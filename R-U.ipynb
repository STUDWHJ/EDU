# %%
# coding: utf-8
import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
from skimage import exposure
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split, KFold
# Out:
# 2022-03-10 18:31:06.685617: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
img_files = next(os.walk(r"/home/weiweili/notebook/WHJ/images2/image"))[2]
msk_files = next(os.walk(r"/home/weiweili/notebook/WHJ/images2/lable"))[2]
img_files.sort()
msk_files.sort()
print(len(img_files))
print(len(msk_files))
X = []
Y = []
for img_fl in tqdm(img_files):
    if (img_fl.split('.')[-1] == 'png'):
        img = cv2.imread('/home/weiweili/notebook/WHJ/images2/image/{}'.format(img_fl))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        resized_img = cv2.resize(img, (256, 192), interpolation=cv2.INTER_CUBIC)
        X.append(resized_img)

        msk = cv2.imread('/home/weiweili/notebook/WHJ/images2/lable/{}'.format(img_fl.split('.')[0] + '.png'), cv2.IMREAD_GRAYSCALE)
        resized_msk = cv2.resize(msk, (256, 192), interpolation=cv2.INTER_CUBIC)
        Y.append(resized_msk)
print(len(X))
print(len(Y))
# Out:
#  39%|████████████████▏                         | 34/88 [00:00<00:00, 336.33it/s]
# 88
# 88
# 100%|██████████████████████████████████████████| 88/88 [00:00<00:00, 328.86it/s]
# 88
# 88

# %%
plt.figure(figsize=(10, 5))
plt.imshow(resized_img)
plt.figure(figsize=(10, 5))
plt.imshow(resized_msk)

# %%
X = np.array(X)
Y = np.array(Y)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
Y_train = Y_train.reshape((Y_train.shape[0], Y_train.shape[1], Y_train.shape[2], 1))
Y_test = Y_test.reshape((Y_test.shape[0], Y_test.shape[1], Y_test.shape[2], 1))
X_train = X_train / 255
X_test = X_test / 255
Y_train = Y_train / 255
Y_test = Y_test / 255
Y_train = np.round(Y_train, 0)
Y_test = np.round(Y_test, 0)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (70, 192, 256, 3)
# (70, 192, 256, 1)
# (18, 192, 256, 3)
# (18, 192, 256, 1)

# %%
X_test1 = exposure.adjust_gamma(X_test, 1.5)
X_train1 = exposure.adjust_gamma(X_train, 1.5)

# %%
plt.imshow(np.array(X_train[0] * 255, np.uint8))
plt.imshow(np.array(Y_train[0][:, :, 0] * 255, np.uint8))
plt.imshow(np.array(X_test[0] * 255, np.uint8))
plt.imshow(np.array(Y_test[0][:, :, 0] * 255, np.uint8))

# %%
def get_kernel():


    k1 = np.array([[1,-3, 1],
                   [-3,  8, -3],
                   [1, -3, 1]])
    
    # Sharpening Spatial Kernel, used in paper
    k2 = np.array([[-1, 0, 1],
                   [-1, 0, 1],
                   [-1, 0, 1]])
    
    k3 = np.array([[-1, -1, -1],
                   [0, 0, 0],
                   [1, 1, 1]])
    
    return k1, k2, k3

# %%
def build_MDE_blocks(layer):

    # Get number of channels in the feature
    in_channels = layer.shape[-1]
    # Get kernel
    _, w, _ = get_kernel()
    # Change dimension
    w = np.expand_dims(w, axis=-1)
    # Repeat filter by in_channels times to get (H, W, in_channels)
    w = np.repeat(w, in_channels, axis=-1)
    # Expand dimension
    w = np.expand_dims(w, axis=-1)
    return w

# %%
def conv3x3(x, out_filters, strides=(1, 1)):
    x = Conv2D(out_filters, 3, padding='same', strides=strides, use_bias=False, kernel_initializer='he_normal')(x)
    return x


def Conv2d_BN(x, nb_filter, kernel_size, strides=(1, 1), padding='same', use_activation=True):
    x = Conv2D(nb_filter, kernel_size, padding=padding, strides=strides, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)
    if use_activation:
        x = Activation('relu')(x)
        return x
    else:
        return x


def basic_Block(input, out_filters, strides=(1, 1), with_conv_shortcut=False):
    x = conv3x3(input, out_filters, strides)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = conv3x3(x, out_filters)
    x = BatchNormalization(axis=3)(x)

    if with_conv_shortcut:
        residual = Conv2D(out_filters, 1, strides=strides, use_bias=False, kernel_initializer='he_normal')(input)
        residual = BatchNormalization(axis=3)(residual)
        x = add([x, residual])
    else:
        x = add([x, input])

    x = Activation('relu')(x)
    return x


def bottleneck_Block(input, out_filters, strides=(1, 1), with_conv_shortcut=False):
    expansion = 4
    de_filters = int(out_filters / expansion)

    x = Conv2D(de_filters, 1, use_bias=False, kernel_initializer='he_normal')(input)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = Conv2D(de_filters, 3, strides=strides, padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = Conv2D(out_filters, 1, use_bias=False, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)

    if with_conv_shortcut:
        residual = Conv2D(out_filters, 1, strides=strides, use_bias=False, kernel_initializer='he_normal')(input)
        residual = BatchNormalization(axis=3)(residual)
        x = add([x, residual])
    else:
        x = add([x, input])

    x = Activation('relu')(x)
    return x

# %%
def Net(img_size, num_classes):
    
    # Kernel size for sharp blocks
    kernel_size = 3
    inputs = Input(img_size)

    conv1_1 = Conv2D(32, 3, strides=(1, 1), padding='same', use_bias=False, kernel_initializer='he_normal')(inputs)
    conv1_1 = BatchNormalization(axis=3)(conv1_1)
    conv1_1 = Activation('relu')(conv1_1)
    conv1 = conv1_1

    conv1_2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(conv1_1)

    # conv2_x  1/4
    conv2_1 = bottleneck_Block(conv1_2, 64, strides=(1, 1), with_conv_shortcut=True)
    conv2_2 = bottleneck_Block(conv2_1, 64)
    conv2_3 = bottleneck_Block(conv2_2, 64)
    conv2 = conv2_3

    # conv3_x  1/8
    conv3_1 = bottleneck_Block(conv2_3, 128, strides=(2, 2), with_conv_shortcut=True)
    conv3_2 = bottleneck_Block(conv3_1, 128)
    conv3_3 = bottleneck_Block(conv3_2, 128)
    conv3_4 = bottleneck_Block(conv3_3, 128)
    conv3 = conv3_4

    # conv4_x  1/16
    conv4_1 = bottleneck_Block(conv3_4, 256, strides=(2, 2), with_conv_shortcut=True)
    conv4_2 = bottleneck_Block(conv4_1, 256)
    conv4_3 = bottleneck_Block(conv4_2, 256)
    conv4_4 = bottleneck_Block(conv4_3, 256)
    conv4_5 = bottleneck_Block(conv4_4, 256)
    conv4_6 = bottleneck_Block(conv4_5, 256)
    conv4 = conv4_6

    # conv5_x  1/32
    conv5_1 = bottleneck_Block(conv4_6, 512, strides=(2, 2), with_conv_shortcut=True)
    conv5_2 = bottleneck_Block(conv5_1, 512)
    conv5_3 = bottleneck_Block(conv5_2, 512)
    conv5 = conv5_3

    # conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    # conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    # pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    #
    # conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    # conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    # pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    #
    # conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    # conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    # pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    #
    # conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    # conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    # pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    #
    # conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    # conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)



    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

   

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    # for multi-class segmentation, use the 'softmax' activation
    conv10 = Conv2D(num_classes, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])

    return model

# %%
# custom metrics
smooth = 1


def jacard(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f + y_pred_f - y_true_f * y_pred_f)
    return intersection / union


def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
# modole callback
checkpointer = ModelCheckpoint("resnet50_unet_model.h5", verbose=0, monitor='val_loss', mode='min', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=1
500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0236 - jacard: 0.9152 - dice_coef: 0.9552 - val_loss: 0.0875 - val_jacard: 0.8515 - val_dice_coef: 0.9183
# Epoch 167/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0229 - jacard: 0.9210 - dice_coef: 0.9585 - val_loss: 0.0878 - val_jacard: 0.8505 - val_dice_coef: 0.9177
# Epoch 168/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0226 - jacard: 0.9186 - dice_coef: 0.9573 - val_loss: 0.0898 - val_jacard: 0.8487 - val_dice_coef: 0.9166
# Epoch 169/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0227 - jacard: 0.9204 - dice_coef: 0.9583 - val_loss: 0.0906 - val_jacard: 0.8480 - val_dice_coef: 0.9163
# Epoch 170/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0229 - jacard: 0.9211 - dice_coef: 0.9587 - val_loss: 0.0909 - val_jacard: 0.8474 - val_dice_coef: 0.9159
# Epoch 171/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0233 - jacard: 0.9196 - dice_coef: 0.9578 - val_loss: 0.0909 - val_jacard: 0.8480 - val_dice_coef: 0.9163
# Epoch 172/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0227 - jacard: 0.9184 - dice_coef: 0.9572 - val_loss: 0.0929 - val_jacard: 0.8472 - val_dice_coef: 0.9158
# Epoch 173/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0226 - jacard: 0.9250 - dice_coef: 0.9609 - val_loss: 0.0907 - val_jacard: 0.8483 - val_dice_coef: 0.9165
# Epoch 174/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0220 - jacard: 0.9231 - dice_coef: 0.9598 - val_loss: 0.0899 - val_jacard: 0.8489 - val_dice_coef: 0.9169
# Epoch 175/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0227 - jacard: 0.9224 - dice_coef: 0.9595 - val_loss: 0.0897 - val_jacard: 0.8482 - val_dice_coef: 0.9164
# Epoch 176/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0232 - jacard: 0.9217 - dice_coef: 0.9590 - val_loss: 0.0897 - val_jacard: 0.8482 - val_dice_coef: 0.9164
# Epoch 177/500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0227 - jacard: 0.9229 - dice_coef: 0.9597 - val_loss: 0.0874 - val_jacard: 0.8503 - val_dice_coef: 0.9177
# Epoch 178/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0224 - jacard: 0.9223 - dice_coef: 0.9593 - val_loss: 0.0885 - val_jacard: 0.8495 - val_dice_coef: 0.9172
# Epoch 179/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0225 - jacard: 0.9234 - dice_coef: 0.9600 - val_loss: 0.0878 - val_jacard: 0.8505 - val_dice_coef: 0.9178
# Epoch 180/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0230 - jacard: 0.9218 - dice_coef: 0.9591 - val_loss: 0.0896 - val_jacard: 0.8488 - val_dice_coef: 0.9168
# Epoch 181/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0228 - jacard: 0.9193 - dice_coef: 0.9577 - val_loss: 0.0910 - val_jacard: 0.8481 - val_dice_coef: 0.9164
# Epoch 182/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0230 - jacard: 0.9198 - dice_coef: 0.9580 - val_loss: 0.0907 - val_jacard: 0.8486 - val_dice_coef: 0.9166
# Epoch 183/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0227 - jacard: 0.9186 - dice_coef: 0.9572 - val_loss: 0.0923 - val_jacard: 0.8473 - val_dice_coef: 0.9159
# Epoch 184/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0225 - jacard: 0.9204 - dice_coef: 0.9583 - val_loss: 0.0900 - val_jacard: 0.8492 - val_dice_coef: 0.9170
# Epoch 185/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0223 - jacard: 0.9215 - dice_coef: 0.9588 - val_loss: 0.0889 - val_jacard: 0.8498 - val_dice_coef: 0.9173
# Epoch 186/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0223 - jacard: 0.9212 - dice_coef: 0.9587 - val_loss: 0.0878 - val_jacard: 0.8511 - val_dice_coef: 0.9182
# Epoch 187/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0222 - jacard: 0.9220 - dice_coef: 0.9592 - val_loss: 0.0880 - val_jacard: 0.8508 - val_dice_coef: 0.9180
# Epoch 188/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0227 - jacard: 0.9240 - dice_coef: 0.9603 - val_loss: 0.0871 - val_jacard: 0.8509 - val_dice_coef: 0.9181
# Epoch 189/500
# 35/35 [==============================] - 1s 32ms/step - loss: 0.0227 - jacard: 0.9185 - dice_coef: 0.9572 - val_loss: 0.0882 - val_jacard: 0.8506 - val_dice_coef: 0.9178
# Epoch 190/500
# 35/35 [==============================] - 1s 33ms/step - loss: 0.0222 - jacard: 0.9205 - dice_coef: 0.9584 - val_loss: 0.0866 - val_jacard: 0.8523 - val_dice_coef: 0.9189
# Epoch 191/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0222 - jacard: 0.
500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0228 - jacard: 0.9232 - dice_coef: 0.9599 - val_loss: 0.0882 - val_jacard: 0.8507 - val_dice_coef: 0.9180
# Epoch 241/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0225 - jacard: 0.9217 - dice_coef: 0.9591 - val_loss: 0.0881 - val_jacard: 0.8507 - val_dice_coef: 0.9179
# Epoch 242/500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0224 - jacard: 0.9237 - dice_coef: 0.9601 - val_loss: 0.0863 - val_jacard: 0.8518 - val_dice_coef: 0.9185
# Epoch 243/500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0223 - jacard: 0.9226 - dice_coef: 0.9595 - val_loss: 0.0863 - val_jacard: 0.8516 - val_dice_coef: 0.9184
# Epoch 244/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0232 - jacard: 0.9202 - dice_coef: 0.9582 - val_loss: 0.0874 - val_jacard: 0.8510 - val_dice_coef: 0.9181
# Epoch 245/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0232 - jacard: 0.9220 - dice_coef: 0.9592 - val_loss: 0.0879 - val_jacard: 0.8502 - val_dice_coef: 0.9176
# Epoch 246/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0230 - jacard: 0.9215 - dice_coef: 0.9589 - val_loss: 0.0883 - val_jacard: 0.8496 - val_dice_coef: 0.9172
# Epoch 247/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0221 - jacard: 0.9253 - dice_coef: 0.9611 - val_loss: 0.0872 - val_jacard: 0.8505 - val_dice_coef: 0.9177
# Epoch 248/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0231 - jacard: 0.9185 - dice_coef: 0.9572 - val_loss: 0.0892 - val_jacard: 0.8493 - val_dice_coef: 0.9171
# Epoch 249/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0234 - jacard: 0.9223 - dice_coef: 0.9594 - val_loss: 0.0886 - val_jacard: 0.8499 - val_dice_coef: 0.9175
# Epoch 250/500
# 35/35 [==============================] - 1s 32ms/step - loss: 0.0226 - jacard: 0.9214 - dice_coef: 0.9588 - val_loss: 0.0908 - val_jacard: 0.8480 - val_dice_coef: 0.9163
# Epoch 251/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0228 - jacard: 0.9193 - dice_coef: 0.9576 - val_loss: 0.0904 - val_jacard: 0.8484 - val_dice_coef: 0.9165
# Epoch 252/500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0224 - jacard: 0.9232 - dice_coef: 0.9599 - val_loss: 0.0907 - val_jacard: 0.8482 - val_dice_coef: 0.9164
# Epoch 253/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0228 - jacard: 0.9241 - dice_coef: 0.9604 - val_loss: 0.0887 - val_jacard: 0.8498 - val_dice_coef: 0.9174
# Epoch 254/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0218 - jacard: 0.9214 - dice_coef: 0.9589 - val_loss: 0.0901 - val_jacard: 0.8485 - val_dice_coef: 0.9166
# ...
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0227 - jacard: 0.9211 - dice_coef: 0.9587 - val_loss: 0.0919 - val_jacard: 0.8475 - val_dice_coef: 0.9161
# Epoch 415/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0228 - jacard: 0.9181 - dice_coef: 0.9570 - val_loss: 0.0925 - val_jacard: 0.8475 - val_dice_coef: 0.9160
# Epoch 416/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0228 - jacard: 0.9210 - dice_coef: 0.9586 - val_loss: 0.0919 - val_jacard: 0.8478 - val_dice_coef: 0.9162
# Epoch 417/500
# 35/35 [==============================] - 1s 32ms/step - loss: 0.0232 - jacard: 0.9176 - dice_coef: 0.9567 - val_loss: 0.0915 - val_jacard: 0.8485 - val_dice_coef: 0.9166
# Epoch 418/500
# 35/35 [==============================] - 1s 34ms/step - loss: 0.0224 - jacard: 0.9213 - dice_coef: 0.9587 - val_loss: 0.0887 - val_jacard: 0.8501 - val_dice_coef: 0.9175
# Epoch 419/500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0228 - jacard: 0.9230 - dice_coef: 0.9598 - val_loss: 0.0891 - val_jacard: 0.8496 - val_dice_coef: 0.9172
# Epoch 420/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0227 - jacard: 0.9224 - dice_coef: 0.9595 - val_loss: 0.0897 - val_jacard: 0.8490 - val_dice_coef: 0.9169
# Epoch 421/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0222 - jacard: 0.9228 - dice_coef: 0.9596 - val_loss: 0.0906 - val_jacard: 0.8487 - val_dice_coef: 0.9167
# Epoch 422/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0226 - jacard: 0.9215 - dice_coef: 0.9589 - val_loss: 0.0897 - val_jacard: 0.8490 - val_dice_coef: 0.9168
# Epoch 423/500
# 35/35 [==============================] - 1s 32ms/step - loss: 0.0230 - jacard: 0.9187 - dice_coef: 0.9574 - val_loss: 0.0915 - val_jacard: 0.8483 - val_dice_coef: 0.9164
# Epoch 424/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0222 - jacard: 0.9181 - dice_coef: 0.9568 - val_loss: 0.0905 - val_jacard: 0.8491 - val_dice_coef: 0.9169
# Epoch 425/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0223 - jacard: 0.9251 - dice_coef: 0.9609 - val_loss: 0.0897 - val_jacard: 0.8494 - val_dice_coef: 0.9171
# Epoch 426/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0222 - jacard: 0.9228 - dice_coef: 0.9596 - val_loss: 0.0884 - val_jacard: 0.8505 - val_dice_coef: 0.9178
# Epoch 427/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0230 - jacard: 0.9214 - dice_coef: 0.9589 - val_loss: 0.0891 - val_jacard: 0.8501 - val_dice_coef: 0.9176
# Epoch 428/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0220 - jacard: 0.9209 - dice_coef: 0.9585 - val_loss: 0.0911 - val_jacard: 0.8486 - val_dice_coef: 0.9167
# Epoch 429/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0224 - jacard: 0.9215 - dice_coef: 0.9589 - val_loss: 0.0909 - val_jacard: 0.8487 - val_dice_coef: 0.9167
# Epoch 430/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0227 - jacard: 0.9257 - dice_coef: 0.9613 - val_loss: 0.0891 - val_jacard: 0.8498 - val_dice_coef: 0.9174
# Epoch 431/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0233 - jacard: 0.9189 - dice_coef: 0.9575 - val_loss: 0.0873 - val_jacard: 0.8512 - val_dice_coef: 0.9182
# Epoch 432/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0228 - jacard: 0.9250 - dice_coef: 0.9609 - val_loss: 0.0860 - val_jacard: 0.8526 - val_dice_coef: 0.9191
# Epoch 433/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0214 - jacard: 0.9232 - dice_coef: 0.9599 - val_loss: 0.0859 - val_jacard: 0.8528 - val_dice_coef: 0.9191
# Epoch 434/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0229 - jacard: 0.9207 - dice_coef: 0.9585 - val_loss: 0.0869 - val_jacard: 0.8514 - val_dice_coef: 0.9184
# Epoch 435/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0225 - jacard: 0.9228 - dice_coef: 0.9597 - val_loss: 0.0868 - val_jacard: 0.8514 - val_dice_coef: 0.9184
# Epoch 436/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0223 - jacard: 0.9199 - dice_coef: 0.9580 - val_loss: 0.0879 - val_jacard: 0.8512 - val_dice_coef: 0.9182
# Epoch 437/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0221 - jacard: 0.9240 - dice_coef: 0.9604 - val_loss: 0.0875 - val_jacard: 0.8513 - val_dice_coef: 0.9183
# Epoch 438/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0218 - jacard: 0.9215 - dice_coef: 0.9589 - val_loss: 0.0881 - val_jacard: 0.8511 - val_dice_coef: 0.9181
# Epoch 439/500
# 35/35 [==============================] - 1s 32ms/step - loss: 0.0223 - jacard: 0.9183 - dice_coef: 0.9571 - val_loss: 0.0904 - val_jacard: 0.8497 - val_dice_coef: 0.9173
# Epoch 440/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0233 - jacard: 0.9206 - dice_coef: 0.9585 - val_loss: 0.0905 - val_jacard: 0.8490 - val_dice_coef: 0.9169
# Epoch 441/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0234 - jacard: 0.9214 - dice_coef: 0.9589 - val_loss: 0.0908 - val_jacard: 0.8488 - val_dice_coef: 0.9168
# Epoch 442/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0236 - jacard: 0.9215 - dice_coef: 0.9589 - val_loss: 0.0896 - val_jacard: 0.8498 - val_dice_coef: 0.9174
# Epoch 443/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0223 - jacard: 0.9210 - dice_coef: 0.9586 - val_loss: 0.0893 - val_jacard: 0.8501 - val_dice_coef: 0.9176
# Epoch 444/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0220 - jacard: 0.9239 - dice_coef: 0.9603 - val_loss: 0.0892 - val_jacard: 0.8505 - val_dice_coef: 0.9179
# Epoch 445/500
# 35/35 [==============================] - 1s 32ms/step - loss: 0.0221 - jacard: 0.9237 - dice_coef: 0.9602 - val_loss: 0.0875 - val_jacard: 0.8520 - val_dice_coef: 0.9187
# Epoch 446/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0232 - jacard: 0.9208 - dice_coef: 0.9585 - val_loss: 0.0888 - val_jacard: 0.8507 - val_dice_coef: 0.9180
# Epoch 447/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0230 - jacard: 0.9190 - dice_coef: 0.9575 - val_loss: 0.0898 - val_jacard: 0.8502 - val_dice_coef: 0.9177
# Epoch 448/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0225 - jacard: 0.9218 - dice_coef: 0.9591 - val_loss: 0.0894 - val_jacard: 0.8502 - val_dice_coef: 0.9177
# Epoch 449/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.
500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0230 - jacard: 0.9181 - dice_coef: 0.9570 - val_loss: 0.0913 - val_jacard: 0.8488 - val_dice_coef: 0.9168
# Epoch 474/500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0222 - jacard: 0.9217 - dice_coef: 0.9591 - val_loss: 0.0905 - val_jacard: 0.8492 - val_dice_coef: 0.9170
# Epoch 475/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0236 - jacard: 0.9219 - dice_coef: 0.9592 - val_loss: 0.0912 - val_jacard: 0.8486 - val_dice_coef: 0.9167
# Epoch 476/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0222 - jacard: 0.9217 - dice_coef: 0.9590 - val_loss: 0.0897 - val_jacard: 0.8496 - val_dice_coef: 0.9173
# Epoch 477/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0235 - jacard: 0.9197 - dice_coef: 0.9579 - val_loss: 0.0897 - val_jacard: 0.8498 - val_dice_coef: 0.9173
# Epoch 478/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0231 - jacard: 0.9193 - dice_coef: 0.9577 - val_loss: 0.0888 - val_jacard: 0.8502 - val_dice_coef: 0.9176
# Epoch 479/500
# 35/35 [==============================] - 1s 32ms/step - loss: 0.0225 - jacard: 0.9216 - dice_coef: 0.9589 - val_loss: 0.0877 - val_jacard: 0.8512 - val_dice_coef: 0.9183
# Epoch 480/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0230 - jacard: 0.9208 - dice_coef: 0.9585 - val_loss: 0.0869 - val_jacard: 0.8514 - val_dice_coef: 0.9184
# Epoch 481/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0218 - jacard: 0.9214 - dice_coef: 0.9588 - val_loss: 0.0876 - val_jacard: 0.8510 - val_dice_coef: 0.9181
# Epoch 482/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0225 - jacard: 0.9213 - dice_coef: 0.9588 - val_loss: 0.0880 - val_jacard: 0.8508 - val_dice_coef: 0.9179
# Epoch 483/500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0223 - jacard: 0.9248 - dice_coef: 0.9608 - val_loss: 0.0879 - val_jacard: 0.8509 - val_dice_coef: 0.9181
# Epoch 484/500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0225 - jacard: 0.9240 - dice_coef: 0.9603 - val_loss: 0.0892 - val_jacard: 0.8502 - val_dice_coef: 0.9176
# Epoch 485/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0221 - jacard: 0.9179 - dice_coef: 0.9569 - val_loss: 0.0907 - val_jacard: 0.8494 - val_dice_coef: 0.9172
# Epoch 486/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0223 - jacard: 0.9213 - dice_coef: 0.9588 - val_loss: 0.0912 - val_jacard: 0.8489 - val_dice_coef: 0.9168
# Epoch 487/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0220 - jacard: 0.9241 - dice_coef: 0.9604 - val_loss: 0.0897 - val_jacard: 0.8496 - val_dice_coef: 0.9172
# Epoch 488/500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0230 - jacard: 0.9190 - dice_coef: 0.9574 - val_loss: 0.0905 - val_jacard: 0.8490 - val_dice_coef: 0.9169
# Epoch 489/500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0222 - jacard: 0.9215 - dice_coef: 0.9589 - val_loss: 0.0902 - val_jacard: 0.8494 - val_dice_coef: 0.9171
# Epoch 490/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0226 - jacard: 0.9216 - dice_coef: 0.9590 - val_loss: 0.0899 - val_jacard: 0.8488 - val_dice_coef: 0.9167
# Epoch 491/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0227 - jacard: 0.9190 - dice_coef: 0.9576 - val_loss: 0.0916 - val_jacard: 0.8474 - val_dice_coef: 0.9159
# Epoch 492/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0221 - jacard: 0.9233 - dice_coef: 0.9599 - val_loss: 0.0904 - val_jacard: 0.8482 - val_dice_coef: 0.9164
# Epoch 493/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0224 - jacard: 0.9173 - dice_coef: 0.9566 - val_loss: 0.0920 - val_jacard: 0.8479 - val_dice_coef: 0.9162
# Epoch 494/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0227 - jacard: 0.9218 - dice_coef: 0.9590 - val_loss: 0.0889 - val_jacard: 0.8500 - val_dice_coef: 0.9175
# Epoch 495/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0233 - jacard: 0.9198 - dice_coef: 0.9579 - val_loss: 0.0899 - val_jacard: 0.8493 - val_dice_coef: 0.9171
# Epoch 496/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0229 - jacard: 0.9177 - dice_coef: 0.9567 - val_loss: 0.0921 - val_jacard: 0.8481 - val_dice_coef: 0.9164
# Epoch 497/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0221 - jacard: 0.9217 - dice_coef: 0.9590 - val_loss: 0.0922 - val_jacard: 0.8475 - val_dice_coef: 0.9159
# Epoch 498/500
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0216 - jacard: 0.9247 - dice_coef: 0.9607 - val_loss: 0.0898 - val_jacard: 0.8495 - val_dice_coef: 0.9172
# Epoch 499/500
# 35/35 [==============================] - 1s 31ms/step - loss: 0.0223 - jacard: 0.9241 - dice_coef: 0.9604 - val_loss: 0.0891 - val_jacard: 0.8499 - val_dice_coef: 0.9174
# Epoch 500/500
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0222 - jacard: 0.9222 - dice_coef: 0.9593 - val_loss: 0.0880 - val_jacard: 0.8513 - val_dice_coef: 0.9183

# %%
history = his.history
loss = history['loss']
jacard = history['jacard']
dice_coef = history['dice_coef']
val_loss = history['val_loss']
val_jacard = history['val_jacard']
val_dice_coef = history['val_dice_coef']

# %%
df = pd.DataFrame(history)
df.to_csv('/home/weiweili/notebook/WHJ/params2/resnet50_unet_histtory.csv')

# %%
# Evaluatete
# Evaluate trained model using Jaccard and Dice metric
yp = model.predict(x=X_test, batch_size=2, verbose=0)
# Round off boolean masks
yp = np.round(yp, 0)

# %%
jacard = 0
dice = 0
sen = 0
pre = 0
jsc = 0
mmc = 0

for i in range(len(Y_test)):
    yp_2 = yp[i].ravel()
    y2 = Y_test[i].ravel()
    intersection = yp_2 * y2
    union = yp_2 + y2 - intersection
    jacard += (np.sum(intersection) / np.sum(union))
    dice += (2. * np.sum(intersection)) / (np.sum(yp_2) + np.sum(y2))
    TP = np.sum(yp_2 * y2)
    TN = np.sum((1-yp_2) * (1-y2))
    FP = np.sum(yp_2 * (1-y2))
    FN = np.sum(y2 * (1-yp_2))
    sen += TP/(TP+FN)
    pre += TP/(TP+FP)
    jsc += TP/(TP+FN+FP)
    mmc += (TP*TN-FP*FN)/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))

# %%
jacard /= len(Y_test)
dice /= len(Y_test)
sen /= len(Y_test)
pre /= len(Y_test)
jsc /= len(Y_test)
mmc /= len(Y_test)

print('Jacard Index : ' + str(jacard))
print('Dice Coefficient : ' + str(dice))
print('sen : ' + str(sen))
print('pre : ' + str(pre))
print('jsc : ' + str(jsc))
print('mmc : ' + str(mmc))
# Out:
# Jacard Index : 0.8744255629746963
# Dice Coefficient : 0.9306071770966979
# sen : 0.9435263620716187
# pre : 0.9216280864609205
# jsc : 0.8744255629746963
# mmc : 0.910631871019705

# %%
os.makedirs('resnet50_unet_res', exist_ok=True)
for i in range(20):
    plt.figure(figsize=(20, 5))
    plt.subplot(1, 3, 1)
    if len(X_test[i].shape) >= 2:
        plt.grid(False)
        plt.imshow(X_test[i].squeeze(), cmap='gray')  # 1-channel image
    else:
        plt.grid(False)
        plt.imshow(X_test[i])  # 3-channel

    plt.title('Input')
    plt.subplot(1, 3, 2)
    plt.grid(False)
    plt.imshow(Y_test[i].reshape(Y_test[i].shape[0], Y_test[i].shape[1]), cmap='magma')  # cmap='magma'
    plt.title('Ground Truth')
    plt.subplot(1, 3, 3)
    plt.grid(False)
    plt.imshow(yp[i].reshape(yp[i].shape[0], yp[i].shape[1]), cmap='magma')
    plt.title('Prediction')

    # Calc jaccard index of predictions
    intersection = yp[i].ravel() * Y_test[i].ravel()
    union = yp[i].ravel() + Y_test[i].ravel() - intersection
    jacard = (np.sum(intersection) / np.sum(union))

    plt.suptitle('Jacard Index: ' + str(np.sum(intersection)) + '/' + str(np.sum(union)) + ' = ' + str(jacard))
    plt.savefig(r"/home/weiweili/notebook/WHJ/params2/resnet50_unet_res/test_%d.tif"%(i))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_420587/2348629147.py in <module>
#       3     plt.figure(figsize=(20, 5))
#       4     plt.subplot(1, 3, 1)
# ----> 5     if len(X_test[i].shape) >= 2:
#       6         plt.grid(False)
#       7         plt.imshow(X_test[i].squeeze(), cmap='gray')  # 1-channel image
#
# IndexError: index 18 is out of bounds for axis 0 with size 18

# %%
X = np.array(X)
Y = np.array(Y)
Y = Y.reshape((Y.shape[0], Y.shape[1], Y.shape[2], 1))
X = X / 255
Y = Y / 255
Y = np.round(Y, 0)
X = exposure.adjust_gamma(X, 1.5)

# %%
kf = KFold(n_splits=5)
k=0

# %%
for train_index, test_index in kf.split(X):
    k+=1
    X_train = X[train_index]
    Y_train = Y[train_index]
    X_test = X[test_index]
    Y_test = Y[test_index]

    def jacard(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        union = K.sum(y_true_f + y_pred_f - y_true_f * y_pred_f)
        return intersection / union

    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    model = SharpUNet((192, 256, 3), 1)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[jacard, dice_coef])
    
    epochs = 100
    his = model.fit(X_train, Y_train,
          batch_size=2,
          epochs=epochs,
          validation_data=(X_test, Y_test),
          callbacks=[reduce_lr],
          shuffle=True)
    history = his.history
    df = pd.DataFrame(history)
    df.to_csv('/home/weiweili/notebook/WHJ/params2/1resenet_unet-histtory_%d.csv'% (k))
    yp = model.predict(x=X_test, batch_size=2, verbose=0)
    yp = np.round(yp, 0)
    jacard = 0
    dice = 0
    sen = 0
    pre = 0
    jsc = 0
    mmc = 0

    for i in range(len(Y_test)):
        yp_2 = yp[i].ravel()
        y2 = Y_test[i].ravel()
        intersection = yp_2 * y2
        union = yp_2 + y2 - intersection
        jacard += (np.sum(intersection) / np.sum(union))
        dice += (2. * np.sum(intersection)) / (np.sum(yp_2) + np.sum(y2))
        TP = np.sum(yp_2 * y2)
        TN = np.sum((1 - yp_2) * (1 - y2))
        FP = np.sum(yp_2 * (1 - y2))
        FN = np.sum(y2 * (1 - yp_2))
        sen += TP / (TP + FN)
        pre += TP / (TP + FP)
        jsc += TP / (TP + FN + FP)
        mmc += (TP * TN - FP * FN) / np.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))

    jacard /= len(Y_test)
    dice /= len(Y_test)
    sen /= len(Y_test)
    pre /= len(Y_test)
    jsc /= len(Y_test)
    mmc /= len(Y_test)

    print("%d-th fold verification:" % (k))
    print('Jacard Index : ' + str(jacard))
    print('Dice Coefficient : ' + str(dice))
    print('sen : ' + str(sen))
    print('pre : ' + str(pre))
    print('jsc : ' + str(jsc))
    print('mmc : ' + str(mmc))

print('ok')
