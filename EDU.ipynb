# %%
# coding: utf-8
import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
from skimage import exposure
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K, regularizers
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split, KFold
# Out:
# 2022-03-10 14:46:33.732805: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
img_files = next(os.walk(r"/home/weiweili/notebook/WHJ/images2/image"))[2]
msk_files = next(os.walk(r"/home/weiweili/notebook/WHJ/images2/lable"))[2]
img_files.sort()
msk_files.sort()
print(len(img_files))
print(len(msk_files))
X = []
Y = []
for img_fl in tqdm(img_files):
    if (img_fl.split('.')[-1] == 'png'):
        img = cv2.imread('/home/weiweili/notebook/WHJ/images2/image/{}'.format(img_fl))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        resized_img = cv2.resize(img, (256, 192), interpolation=cv2.INTER_CUBIC)
        X.append(resized_img)

        msk = cv2.imread('/home/weiweili/notebook/WHJ/images2/lable/{}'.format(img_fl.split('.')[0] + '.png'), cv2.IMREAD_GRAYSCALE)
        resized_msk = cv2.resize(msk, (256, 192), interpolation=cv2.INTER_CUBIC)
        Y.append(resized_msk)
print(len(X))
print(len(Y))
# Out:
#  39%|████████████████▏                         | 34/88 [00:00<00:00, 331.03it/s]
# 88
# 88
# 100%|██████████████████████████████████████████| 88/88 [00:00<00:00, 324.25it/s]
# 88
# 88

# %%
plt.figure(figsize=(10, 5))
plt.imshow(resized_img)
plt.figure(figsize=(10, 5))
plt.imshow(resized_msk)

# %%
X = np.array(X)
Y = np.array(Y)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
Y_train = Y_train.reshape((Y_train.shape[0], Y_train.shape[1], Y_train.shape[2], 1))
Y_test = Y_test.reshape((Y_test.shape[0], Y_test.shape[1], Y_test.shape[2], 1))
X_train = X_train / 255
X_test = X_test / 255
Y_train = Y_train / 255
Y_test = Y_test / 255
Y_train = np.round(Y_train, 0)
Y_test = np.round(Y_test, 0)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (70, 192, 256, 3)
# (70, 192, 256, 1)
# (18, 192, 256, 3)
# (18, 192, 256, 1)

# %%
X_test1 = exposure.adjust_gamma(X_test, 1.5)
X_train1 = exposure.adjust_gamma(X_train, 1.5)

# %%
plt.imshow(np.array(X_train[0] * 255, np.uint8))
plt.imshow(np.array(Y_train[0][:, :, 0] * 255, np.uint8))
plt.imshow(np.array(X_test[0] * 255, np.uint8))
plt.imshow(np.array(Y_test[0][:, :, 0] * 255, np.uint8))

# %%
# sharp block
def get_kernel():
    """
    See https://setosa.io/ev/image-kernels/
    """

    k1 = np.array([[1,-3, 1],
                   [-3,  8, -3],
                   [1, -3, 1]])
    
    # Sharpening Spatial Kernel, used in paper
    k2 = np.array([[-1, 0, 1],
                   [-1, 0, 1],
                   [-1, 0, 1]])
    
    k3 = np.array([[-1, -1, -1],
                   [0, 0, 0],
                   [1, 1, 1]])
    
    return k1, k2, k3

# %%
def build_sharp_blocks(layer):
    """
    Sharp Blocks
    """
    # Get number of channels in the feature
    in_channels = layer.shape[-1]
    # Get kernel
    _, w, _ = get_kernel()
    # Change dimension
    w = np.expand_dims(w, axis=-1)
    # Repeat filter by in_channels times to get (H, W, in_channels)
    w = np.repeat(w, in_channels, axis=-1)
    # Expand dimension
    w = np.expand_dims(w, axis=-1)
    return w

# %%
def DenseBlock(channels,inputs):

    conv1_1 = Conv2D(channels, (1, 1),activation=None, padding='same')(inputs)
    conv1_1=BatchActivate(conv1_1)
    conv1_2 = Conv2D(channels//4, (3, 3), activation=None, padding='same')(conv1_1)
    conv1_2 = BatchActivate(conv1_2)

    conv2=concatenate([inputs,conv1_2])
    conv2_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv2)
    conv2_1 = BatchActivate(conv2_1)
    conv2_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv2_1)
    conv2_2 = BatchActivate(conv2_2)

    conv3 = concatenate([inputs, conv1_2,conv2_2])
    conv3_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv3)
    conv3_1 = BatchActivate(conv3_1)
    conv3_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv3_1)
    conv3_2 = BatchActivate(conv3_2)

    conv4 = concatenate([inputs, conv1_2, conv2_2,conv3_2])
    conv4_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv4)
    conv4_1 = BatchActivate(conv4_1)
    conv4_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv4_1)
    conv4_2 = BatchActivate(conv4_2)
    result=concatenate([inputs,conv1_2, conv2_2,conv3_2,conv4_2])
    return result

def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def SharpUNet(img_size, num_classes):
    "Unet with sharp Blocks in skip connections"

    # Kernel size for sharp blocks
    kernel_size = 3
    inputs = Input(img_size)

    # conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    # conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    # pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    #
    # conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    # conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    # pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    #
    # conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    # conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    # pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    #
    # conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    # conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    # pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    #
    # conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    # conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    start_neurons = 32

    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(inputs)
    conv1 = BatchActivate(conv1)
    pool0 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = DenseBlock(start_neurons * 1, pool0)

    pool1 = MaxPooling2D((2, 2))(conv2)
    conv3 = DenseBlock(start_neurons * 2, pool1)

    pool2 = MaxPooling2D((2, 2))(conv3)
    conv4 = DenseBlock(start_neurons * 4, pool2)

    pool3 = MaxPooling2D((2, 2))(conv4)
    conv5 = DenseBlock(start_neurons * 8, pool3)

    # Skip connection 1
    # 1. Get sharpening kernel weights(1, H, W, channels) 
    W1 = build_sharp_blocks(conv4)
    # 2. Build depthwise convolutional layer with random weights
    sb1 = DepthwiseConv2D(kernel_size, use_bias=False, padding='same')
    # 3. Pass input to layer
    conv4 = sb1(conv4)
    # 4. Set filters as layer weights 
    sb1.set_weights([W1])
    # 5. Dont update weights
    sb1.trainable = False

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    # Skip connection 2
    W2 = build_sharp_blocks(conv3)
    sb2 = DepthwiseConv2D(kernel_size, use_bias=False, padding='same')
    conv3 = sb2(conv3)
    sb2.set_weights([W2])
    sb2.trainable = False

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    # Skip connection 3
    W3 = build_sharp_blocks(conv2)
    sb3 = DepthwiseConv2D(kernel_size, use_bias=False, padding='same')
    conv2 = sb3(conv2)
    sb3.set_weights([W3])
    sb3.trainable = False

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    # Skip connection 4
    W4 = build_sharp_blocks(conv1)
    sb4 = DepthwiseConv2D(kernel_size, use_bias=False, padding='same')
    conv1 = sb4(conv1)
    sb4.set_weights([W4])
    sb4.trainable = False

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    # for multi-class segmentation, use the 'softmax' activation
    conv10 = Conv2D(num_classes, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])

    return model

# %%
# custom metrics
smooth = 1


def jacard(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f + y_pred_f - y_true_f * y_pred_f)
    return intersection / union


def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
# modole callback
checkpointer = ModelCheckpoint("densenet_unet_model.h5", verbose=0, monitor='val_loss', mode='min', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=1, min_lr=1e-8, mode='min')

# %%
# Build model
model = SharpUNet((192, 256, 3), 1)
model.summary()
# Out:
# 2022-03-10 14:46:36.105917: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-03-10 14:46:36.115750: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:3b:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-03-10 14:46:36.115884: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-10 14:46:36.119130: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-03-10 14:46:36.122488: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-03-10 14:46:36.123019: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-03-10 14:46:36.126477: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-03-10 14:46:36.128089: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-03-10 14:46:36.132437: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-03-10 14:46:36.135927: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-03-10 14:46:36.136692: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-10 14:46:36.154363: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 3400000000 Hz
# 2022-03-10 14:46:36.161603: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55dd35677450 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-03-10 14:46:36.161623: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-03
v2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 192, 256, 1)  33          conv2d_40[0][0]
# ==================================================================================================
# Total params: 4,327,297
# Trainable params: 4,318,113
# Non-trainable params: 9,184
# __________________________________________________________________________________________________

# %%
# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[jacard, dice_coef])

# %%
# Train
epochs = 500
his = model.fit(X_train, Y_train,
          batch_size=2,
          epochs=epochs,
          validation_data=(X_test, Y_test),
          callbacks=[reduce_lr, checkpointer],
          shuffle=True)
# Out:
# Epoch 1/500
# 2022-03-10 14:46:40.945755: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-03-10 14:46:42.203816: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 35/35 [==============================] - 2s 52ms/step - loss: 0.4941 - jacard: 0.1610 - dice_coef: 0.2731 - val_loss: 0.6394 - val_jacard: 0.1795 - val_dice_coef: 0.3015
# Epoch 2/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.4171 - jacard: 0.2071 - dice_coef: 0.3392 - val_loss: 0.6831 - val_jacard: 0.1926 - val_dice_coef: 0.3182
# Epoch 3/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.3431 - jacard: 0.2516 - dice_coef: 0.3977 - val_loss: 0.6542 - val_jacard: 0.1605 - val_dice_coef: 0.2727
# Epoch 4/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.2359 - jacard: 0.4288 - dice_coef: 0.5897 - val_loss: 0.8370 - val_jacard: 0.0616 - val_dice_coef: 0.1156
# Epoch 5/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.2063 - jacard: 0.4773 - dice_coef: 0.6364 - val_loss: 1.9012 - val_jacard: 0.0173 - val_dice_coef: 0.0337
# Epoch 6/500
# 35/35 [==============================] - 1s 28ms/step - loss: 0.1883 - jacard: 0.5319 - dice_coef: 0.6815 - val_loss: 0.8627 - val_jacard: 0.0676 - val_dice_coef: 0.1251
# Epoch 7/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.1344 - jacard: 0.6547 - dice_coef: 0.7803 - val_loss: 1.7982 - val_jacard: 0.0045 - val_dice_coef: 0.0091
# Epoch 8/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0934 - jacard: 0.7214 - dice_coef: 0.8319 - val_loss: 1.2487 - val_jacard: 0.0357 - val_dice_coef: 0.0680
# Epoch 9/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0681 - jacard: 0.7744 - dice_coef: 0.8679 - val_loss: 2.5355 - val_jacard: 0.0118 - val_dice_coef: 0.0229
# Epoch 10/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0596 - jacard: 0.8108 - dice_coef: 0.8928 - val_loss: 2.1824 - val_jacard: 0.0241 - val_dice_coef: 0.0457
# Epoch 11/500
# 35/35 [==============================] - ETA: 0s - loss: 0.0842 - jacard: 0.7746 - dice_coef: 0.8682
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0842 - jacard: 0.7746 - dice_coef: 0.8682 - val_loss: 0.6944 - val_jacard: 0.3377 - val_dice_coef: 0.4945
# Epoch 12/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0839 - jacard: 0.7279 - dice_coef: 0.8353 - val_loss: 0.9411 - val_jacard: 0.3224 - val_dice_coef: 0.4668
# Epoch 13/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0458 - jacard: 0.8338 - dice_coef: 0.9068 - val_loss: 0.8446 - val_jacard: 0.4187 - val_dice_coef: 0.5673
# Epoch 14/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0384 - jacard: 0.8586 - dice_coef: 0.9218 - val_loss: 0.7055 - val_jacard: 0.4720 - val_dice_coef: 0.6192
# Epoch 15/500
# 35/35 [==============================] - 1s 34ms/step - loss: 0.0318 - jacard: 0.8871 - dice_coef: 0.9390 - val_loss: 0.5192 - val_jacard: 0.5675 - val_dice_coef: 0.7047
# Epoch 16/500
# 35/35 [==============================] - 1s 35ms/step - loss: 0.0299 - jacard: 0.8942 - dice_coef: 0.9432 - val_loss: 0.3023 - val_jacard: 0.6836 - val_dice_coef: 0.7989
# Epoch 17/500
# 35/35 [==============================] - 1s 35ms/step - loss: 0.0271 - jacard: 0.9010 - dice_coef: 0.9473 - val_loss: 0.1665 - val_jacard: 0.7581 - val_dice_coef: 0.8553
# Epoch 18/500
# 35/35 [==============================] - 1s 35ms/step - loss: 0.
500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0125 - jacard: 0.9544 - dice_coef: 0.9766 - val_loss: 0.0309 - val_jacard: 0.9417 - val_dice_coef: 0.9698
# Epoch 40/500
# 35/35 [==============================] - 1s 34ms/step - loss: 0.0115 - jacard: 0.9563 - dice_coef: 0.9776 - val_loss: 0.0291 - val_jacard: 0.9450 - val_dice_coef: 0.9715
# Epoch 41/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0122 - jacard: 0.9580 - dice_coef: 0.9785 - val_loss: 0.0308 - val_jacard: 0.9439 - val_dice_coef: 0.9710
# Epoch 42/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0112 - jacard: 0.9600 - dice_coef: 0.9795 - val_loss: 0.0337 - val_jacard: 0.9441 - val_dice_coef: 0.9712
# Epoch 43/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0115 - jacard: 0.9575 - dice_coef: 0.9782 - val_loss: 0.0346 - val_jacard: 0.9422 - val_dice_coef: 0.9701
# Epoch 44/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0114 - jacard: 0.9595 - dice_coef: 0.9792 - val_loss: 0.0391 - val_jacard: 0.9423 - val_dice_coef: 0.9702
# Epoch 45/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0106 - jacard: 0.9612 - dice_coef: 0.9802 - val_loss: 0.0381 - val_jacard: 0.9442 - val_dice_coef: 0.9712
# Epoch 46/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0106 - jacard: 0.9627 - dice_coef: 0.9809 - val_loss: 0.0327 - val_jacard: 0.9470 - val_dice_coef: 0.9727
# Epoch 47/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0101 - jacard: 0.9640 - dice_coef: 0.9816 - val_loss: 0.0312 - val_jacard: 0.9480 - val_dice_coef: 0.9732
# Epoch 48/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0104 - jacard: 0.9613 - dice_coef: 0.9802 - val_loss: 0.0364 - val_jacard: 0.9439 - val_dice_coef: 0.9710
# Epoch 49/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0097 - jacard: 0.9656 - dice_coef: 0.9825 - val_loss: 0.0327 - val_jacard: 0.9489 - val_dice_coef: 0.9737
# Epoch 50/500
# 34/35 [============================>.] - ETA: 0s - loss: 0.0094 - jacard: 0.9652 - dice_coef: 0.9822
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0094 - jacard: 0.9654 - dice_coef: 0.9824 - val_loss: 0.0329 - val_jacard: 0.9494 - val_dice_coef: 0.9739
# Epoch 51/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0091 - jacard: 0.9671 - dice_coef: 0.9832 - val_loss: 0.0304 - val_jacard: 0.9509 - val_dice_coef: 0.9747
# Epoch 52/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0091 - jacard: 0.9668 - dice_coef: 0.9831 - val_loss: 0.0301 - val_jacard: 0.9512 - val_dice_coef: 0.9749
# Epoch 53/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0089 - jacard: 0.9674 - dice_coef: 0.9834 - val_loss: 0.0298 - val_jacard: 0.9515 - val_dice_coef: 0.9750
# Epoch 54/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0088 - jacard: 0.9683 - dice_coef: 0.9839 - val_loss: 0.0313 - val_jacard: 0.9513 - val_dice_coef: 0.9749
# Epoch 55/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0090 - jacard: 0.9674 - dice_coef: 0.9834 - val_loss: 0.0320 - val_jacard: 0.9511 - val_dice_coef: 0.9748
# Epoch 56/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0090 - jacard: 0.9651 - dice_coef: 0.9822 - val_loss: 0.0339 - val_jacard: 0.9504 - val_dice_coef: 0.9745
# Epoch 57/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0088 - jacard: 0.9681 - dice_coef: 0.9838 - val_loss: 0.0313 - val_jacard: 0.9516 - val_dice_coef: 0.9751
# Epoch 58/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0088 - jacard: 0.9687 - dice_coef: 0.9841 - val_loss: 0.0321 - val_jacard: 0.9516 - val_dice_coef: 0.9751
# Epoch 59/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0088 - jacard: 0.9670 - dice_coef: 0.9832 - val_loss: 0.0326 - val_jacard: 0.9515 - val_dice_coef: 0.9750
# Epoch 60/500
# 34/35 [============================>.] - ETA: 0s - loss: 0.0086 - jacard: 0.9694 - dice_coef: 0.9844
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0085 - jacard: 0.9694 - dice_coef: 0.9844 - val_loss: 0.0337 - val_jacard: 0.9512 - val_dice_coef: 0.9749
# Epoch 61/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9685 - dice_coef: 0.9839 - val_loss: 0.0342 - val_jacard: 0.9511 - val_dice_coef: 0.9748
# Epoch 62/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0087 - jacard: 0.9694 - dice_coef: 0.9844 - val_loss: 0.0346 - val_jacard: 0.9509 - val_dice_coef: 0.9747
# Epoch 63/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0084 - jacard: 0.9704 - dice_coef: 0.9849 - val_loss: 0.0330 - val_jacard: 0.9515 - val_dice_coef: 0.9751
# Epoch 64/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0084 - jacard: 0.9686 - dice_coef: 0.9840 - val_loss: 0.0328 - val_jacard: 0.9517 - val_dice_coef: 0.9751
# Epoch
500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0084 - jacard: 0.9686 - dice_coef: 0.9840 - val_loss: 0.0326 - val_jacard: 0.9519 - val_dice_coef: 0.9752
# Epoch 440/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9686 - dice_coef: 0.9840 - val_loss: 0.0323 - val_jacard: 0.9520 - val_dice_coef: 0.9753
# Epoch 441/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9681 - dice_coef: 0.9838 - val_loss: 0.0324 - val_jacard: 0.9519 - val_dice_coef: 0.9753
# Epoch 442/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9693 - dice_coef: 0.9844 - val_loss: 0.0317 - val_jacard: 0.9522 - val_dice_coef: 0.9754
# Epoch 443/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9677 - dice_coef: 0.9835 - val_loss: 0.0321 - val_jacard: 0.9520 - val_dice_coef: 0.9753
# Epoch 444/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0084 - jacard: 0.9672 - dice_coef: 0.9833 - val_loss: 0.0324 - val_jacard: 0.9520 - val_dice_coef: 0.9753
# Epoch 445/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0084 - jacard: 0.9693 - dice_coef: 0.9844 - val_loss: 0.0328 - val_jacard: 0.9518 - val_dice_coef: 0.9752
# Epoch 446/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0088 - jacard: 0.9690 - dice_coef: 0.9842 - val_loss: 0.0324 - val_jacard: 0.9519 - val_dice_coef: 0.9753
# Epoch 447/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9669 - dice_coef: 0.9831 - val_loss: 0.0317 - val_jacard: 0.9522 - val_dice_coef: 0.9754
# Epoch 448/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0084 - jacard: 0.9684 - dice_coef: 0.9839 - val_loss: 0.0318 - val_jacard: 0.9522 - val_dice_coef: 0.9754
# Epoch 449/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0086 - jacard: 0.9677 - dice_coef: 0.9835 - val_loss: 0.0320 - val_jacard: 0.9521 - val_dice_coef: 0.9754
# Epoch 450/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0086 - jacard: 0.9691 - dice_coef: 0.9843 - val_loss: 0.0313 - val_jacard: 0.9524 - val_dice_coef: 0.9755
# Epoch 451/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0087 - jacard: 0.9682 - dice_coef: 0.9838 - val_loss: 0.0318 - val_jacard: 0.9522 - val_dice_coef: 0.9754
# Epoch 452/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9678 - dice_coef: 0.9836 - val_loss: 0.0320 - val_jacard: 0.9521 - val_dice_coef: 0.9754
# Epoch 453/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0086 - jacard: 0.9689 - dice_coef: 0.9842 - val_loss: 0.0313 - val_jacard: 0.9524 - val_dice_coef: 0.9755
# Epoch 454/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9701 - dice_coef: 0.9848 - val_loss: 0.0304 - val_jacard: 0.9527 - val_dice_coef: 0.9757
# Epoch 455/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0085 - jacard: 0.9686 - dice_coef: 0.9840 - val_loss: 0.0304 - val_jacard: 0.9527 - val_dice_coef: 0.9757
# Epoch 456/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0086 - jacard: 0.9691 - dice_coef: 0.9843 - val_loss: 0.0317 - val_jacard: 0.9522 - val_dice_coef: 0.9754
# Epoch 457/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0085 - jacard: 0.9679 - dice_coef: 0.9836 - val_loss: 0.0322 - val_jacard: 0.9520 - val_dice_coef: 0.9753
# Epoch 458/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9692 - dice_coef: 0.9843 - val_loss: 0.0332 - val_jacard: 0.9517 - val_dice_coef: 0.9751
# Epoch 459/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9692 - dice_coef: 0.9843 - val_loss: 0.0331 - val_jacard: 0.9517 - val_dice_coef: 0.9751
# Epoch 460/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9697 - dice_coef: 0.9846 - val_loss: 0.0334 - val_jacard: 0.9516 - val_dice_coef: 0.9751
# Epoch 461/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9686 - dice_coef: 0.9840 - val_loss: 0.0335 - val_jacard: 0.9515 - val_dice_coef: 0.9751
# Epoch 462/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9698 - dice_coef: 0.9847 - val_loss: 0.0338 - val_jacard: 0.9514 - val_dice_coef: 0.9750
# Epoch 463/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9690 - dice_coef: 0.9842 - val_loss: 0.0324 - val_jacard: 0.9519 - val_dice_coef: 0.9753
# Epoch 464/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0084 - jacard: 0.9690 - dice_coef: 0.9842 - val_loss: 0.0332 - val_jacard: 0.9517 - val_dice_coef: 0.9751
# Epoch 465/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0084 - jacard: 0.9703 - dice_coef: 0.9849 - val_loss: 0.0331 - val_jacard: 0.9517 - val_dice_coef: 0.9752
# Epoch 466/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9700 - dice_coef: 0.9847 - val_loss: 0.0345 - val_jacard: 0.9512 - val_dice_coef: 0.9749
# Epoch 467/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9683 - dice_coef: 0.9839 - val_loss: 0.0339 - val_jacard: 0.9514 - val_dice_coef: 0.9750
# Epoch 468/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0086 - jacard: 0.9690 - dice_coef: 0.9842 - val_loss: 0.0329 - val_jacard: 0.9518 - val_dice_coef: 0.9752
# Epoch 469/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0084 - jacard: 0.9680 - dice_coef: 0.9837 - val_loss: 0.0340 - val_jacard: 0.9514 - val_dice_coef: 0.9750
# Epoch 470/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0087 - jacard: 0.9675 - dice_coef: 0.9834 - val_loss: 0.0335 - val_jacard: 0.9516 - val_dice_coef: 0.9751
# Epoch 471/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9705 - dice_coef: 0.9850 - val_loss: 0.0328 - val_jacard: 0.9518 - val_dice_coef: 0.9752
# Epoch 472/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9702 - dice_coef: 0.9848 - val_loss: 0.0319 - val_jacard: 0.9521 - val_dice_coef: 0.9754
# Epoch 473/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0084 - jacard: 0.9693 - dice_coef: 0.9844 - val_loss: 0.0313 - val_jacard: 0.9523 - val_dice_coef: 0.9755
# Epoch 474/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0084 - jacard: 0.9699 - dice_coef: 0.9847 - val_loss: 0.0323 - val_jacard: 0.9519 - val_dice_coef: 0.9753
# Epoch 475/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0087 - jacard: 0.9676 - dice_coef: 0.9835 - val_loss: 0.0322 - val_jacard: 0.9520 - val_dice_coef: 0.9753
# Epoch 476/500
# 35/35 [==============================] - 1s 23ms/step - loss: 0.0085 - jacard: 0.9693 - dice_coef: 0.9844 - val_loss: 0.0330 - val_jacard: 0.9517 - val_dice_coef: 0.9751
# Epoch 477/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9681 - dice_coef: 0.9837 - val_loss: 0.0326 - val_jacard: 0.9518 - val_dice_coef: 0.9752
# Epoch 478/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9678 - dice_coef: 0.9836 - val_loss: 0.0341 - val_jacard: 0.9513 - val_dice_coef: 0.9749
# Epoch 479/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9687 - dice_coef: 0.9840 - val_loss: 0.0334 - val_jacard: 0.9515 - val_dice_coef: 0.9751
# Epoch 480/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0087 - jacard: 0.9685 - dice_coef: 0.9840 - val_loss: 0.0341 - val_jacard: 0.9512 - val_dice_coef: 0.9749
# Epoch 481/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0087 - jacard: 0.9686 - dice_coef: 0.9840 - val_loss: 0.0342 - val_jacard: 0.9511 - val_dice_coef: 0.9748
# Epoch 482/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0084 - jacard: 0.9706 - dice_coef: 0.9851 - val_loss: 0.0338 - val_jacard: 0.9513 - val_dice_coef: 0.9749
# Epoch 483/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9688 - dice_coef: 0.9841 - val_loss: 0.0327 - val_jacard: 0.9518 - val_dice_coef: 0.9752
# Epoch 484/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0085 - jacard: 0.9690 - dice_coef: 0.9842 - val_loss: 0.0323 - val_jacard: 0.9520 - val_dice_coef: 0.9753
# Epoch 485/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0088 - jacard: 0.9688 - dice_coef: 0.9841 - val_loss: 0.0317 - val_jacard: 0.9521 - val_dice_coef: 0.9754
# Epoch 486/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0086 - jacard: 0.9683 - dice_coef: 0.9839 - val_loss: 0.0306 - val_jacard: 0.9526 - val_dice_coef: 0.9756
# Epoch 487/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0088 - jacard: 0.9693 - dice_coef: 0.9844 - val_loss: 0.0312 - val_jacard: 0.9524 - val_dice_coef: 0.9755
# Epoch 488/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9685 - dice_coef: 0.9840 - val_loss: 0.0312 - val_jacard: 0.9524 - val_dice_coef: 0.9755
# Epoch 489/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0085 - jacard: 0.9689 - dice_coef: 0.9841 - val_loss: 0.0303 - val_jacard: 0.9528 - val_dice_coef: 0.9757
# Epoch 490/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0086 - jacard: 0.9682 - dice_coef: 0.9838 - val_loss: 0.0303 - val_jacard: 0.9528 - val_dice_coef: 0.9757
# Epoch 491/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0084 - jacard: 0.9688 - dice_coef: 0.9841 - val_loss: 0.0309 - val_jacard: 0.9526 - val_dice_coef: 0.9756
# Epoch 492/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0084 - jacard: 0.9680 - dice_coef: 0.9837 - val_loss: 0.0316 - val_jacard: 0.9523 - val_dice_coef: 0.9755
# Epoch 493/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9696 - dice_coef: 0.9845 - val_loss: 0.0317 - val_jacard: 0.9522 - val_dice_coef: 0.9754
# Epoch 494/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9683 - dice_coef: 0.9838 - val_loss: 0.0313 - val_jacard: 0.9524 - val_dice_coef: 0.9755
# Epoch 495/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0084 - jacard: 0.9688 - dice_coef: 0.9841 - val_loss: 0.0304 - val_jacard: 0.9527 - val_dice_coef: 0.9757
# Epoch 496/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0086 - jacard: 0.9687 - dice_coef: 0.9841 - val_loss: 0.0316 - val_jacard: 0.9523 - val_dice_coef: 0.9755
# Epoch 497/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9693 - dice_coef: 0.9844 - val_loss: 0.0317 - val_jacard: 0.9523 - val_dice_coef: 0.9755
# Epoch 498/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0085 - jacard: 0.9695 - dice_coef: 0.9845 - val_loss: 0.0310 - val_jacard: 0.9525 - val_dice_coef: 0.9756
# Epoch 499/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - jacard: 0.9689 - dice_coef: 0.9841 - val_loss: 0.0310 - val_jacard: 0.9525 - val_dice_coef: 0.9756
# Epoch 500/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0085 - jacard: 0.9686 - dice_coef: 0.9840 - val_loss: 0.0328 - val_jacard: 0.9518 - val_dice_coef: 0.9752

# %%
history = his.history
loss = history['loss']
jacard = history['jacard']
dice_coef = history['dice_coef']
val_loss = history['val_loss']
val_jacard = history['val_jacard']
val_dice_coef = history['val_dice_coef']

# %%
df = pd.DataFrame(history)
df.to_csv('/home/weiweili/notebook/WHJ/params2/densenet_unet+mde_histtory.csv')

# %%
# Evaluatete
# Evaluate trained model using Jaccard and Dice metric
yp = model.predict(x=X_test, batch_size=2, verbose=0)
# Round off boolean masks
yp = np.round(yp, 0)

# %%
jacard = 0
dice = 0
sen = 0
pre = 0
jsc = 0
mmc = 0

for i in range(len(Y_test)):
    yp_2 = yp[i].ravel()
    y2 = Y_test[i].ravel()
    intersection = yp_2 * y2
    union = yp_2 + y2 - intersection
    jacard += (np.sum(intersection) / np.sum(union))
    dice += (2. * np.sum(intersection)) / (np.sum(yp_2) + np.sum(y2))
    TP = np.sum(yp_2 * y2)
    TN = np.sum((1-yp_2) * (1-y2))
    FP = np.sum(yp_2 * (1-y2))
    FN = np.sum(y2 * (1-yp_2))
    sen += TP/(TP+FN)
    pre += TP/(TP+FP)
    jsc += TP/(TP+FN+FP)
    mmc += (TP*TN-FP*FN)/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))

# %%
jacard /= len(Y_test)
dice /= len(Y_test)
sen /= len(Y_test)
pre /= len(Y_test)
jsc /= len(Y_test)
mmc /= len(Y_test)

print('Jacard Index : ' + str(jacard))
print('Dice Coefficient : ' + str(dice))
print('sen : ' + str(sen))
print('pre : ' + str(pre))
print('jsc : ' + str(jsc))
print('mmc : ' + str(mmc))
# Out:
# Jacard Index : 0.9543328859899957
# Dice Coefficient : 0.9762841443852286
# sen : 0.9839738708032618
# pre : 0.9696093697239712
# jsc : 0.9543328859899957
# mmc : 0.9703261704092411

# %%
os.makedirs('densenet_unet+med_res', exist_ok=True)
for i in range(20):
    plt.figure(figsize=(20, 5))
    plt.subplot(1, 3, 1)
    if len(X_test[i].shape) >= 2:
        plt.grid(False)
        plt.imshow(X_test[i].squeeze(), cmap='gray')  # 1-channel image
    else:
        plt.grid(False)
        plt.imshow(X_test[i])  # 3-channel

    plt.title('Input')
    plt.subplot(1, 3, 2)
    plt.grid(False)
    plt.imshow(Y_test[i].reshape(Y_test[i].shape[0], Y_test[i].shape[1]), cmap='magma')  # cmap='magma'
    plt.title('Ground Truth')
    plt.subplot(1, 3, 3)
    plt.grid(False)
    plt.imshow(yp[i].reshape(yp[i].shape[0], yp[i].shape[1]), cmap='magma')
    plt.title('Prediction')

    # Calc jaccard index of predictions
    intersection = yp[i].ravel() * Y_test[i].ravel()
    union = yp[i].ravel() + Y_test[i].ravel() - intersection
    jacard = (np.sum(intersection) / np.sum(union))

    plt.suptitle('Jacard Index: ' + str(np.sum(intersection)) + '/' + str(np.sum(union)) + ' = ' + str(jacard))
    plt.savefig(r"/home/weiweili/notebook/WHJ/params2/densenet_unet+mde_res/test_%d.tif"%(i))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_365094/2045055638.py in <module>
#       3     plt.figure(figsize=(20, 5))
#       4     plt.subplot(1, 3, 1)
# ----> 5     if len(X_test[i].shape) >= 2:
#       6         plt.grid(False)
#       7         plt.imshow(X_test[i].squeeze(), cmap='gray')  # 1-channel image
#
# IndexError: index 18 is out of bounds for axis 0 with size 18

# %%
X = np.array(X)
Y = np.array(Y)
Y = Y.reshape((Y.shape[0], Y.shape[1], Y.shape[2], 1))
X = X / 255
Y = Y / 255
Y = np.round(Y, 0)
X = exposure.adjust_gamma(X, 1.5)

# %%
kf = KFold(n_splits=5)
k=0

# %%
for train_index, test_index in kf.split(X):
    k+=1
    X_train = X[train_index]
    Y_train = Y[train_index]
    X_test = X[test_index]
    Y_test = Y[test_index]

    def jacard(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        union = K.sum(y_true_f + y_pred_f - y_true_f * y_pred_f)
        return intersection / union

    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    model = SharpUNet((192, 256, 3), 1)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[jacard, dice_coef])
    
    epochs = 500
    his = model.fit(X_train, Y_train,
          batch_size=2,
          epochs=epochs,
          validation_data=(X_test, Y_test),
          callbacks=[reduce_lr],
          shuffle=True)
    history = his.history
    df = pd.DataFrame(history)
    df.to_csv('/home/weiweili/notebook/WHJ/params2/1densenet_unet+mde-histtory_%d.csv'% (k))
    yp = model.predict(x=X_test, batch_size=2, verbose=0)
    yp = np.round(yp, 0)
    jacard = 0
    dice = 0
    sen = 0
    pre = 0
    jsc = 0
    mmc = 0

    for i in range(len(Y_test)):
        yp_2 = yp[i].ravel()
        y2 = Y_test[i].ravel()
        intersection = yp_2 * y2
        union = yp_2 + y2 - intersection
        jacard += (np.sum(intersection) / np.sum(union))
        dice += (2. * np.sum(intersection)) / (np.sum(yp_2) + np.sum(y2))
        TP = np.sum(yp_2 * y2)
        TN = np.sum((1 - yp_2) * (1 - y2))
        FP = np.sum(yp_2 * (1 - y2))
        FN = np.sum(y2 * (1 - yp_2))
        sen += TP / (TP + FN)
        pre += TP / (TP + FP)
        jsc += TP / (TP + FN + FP)
        mmc += (TP * TN - FP * FN) / np.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))

    jacard /= len(Y_test)
    dice /= len(Y_test)
    sen /= len(Y_test)
    pre /= len(Y_test)
    jsc /= len(Y_test)
    mmc /= len(Y_test)

    print("%d-th fold verification:" % (k))
    print('Jacard Index : ' + str(jacard))
    print('Dice Coefficient : ' + str(dice))
    print('sen : ' + str(sen))
    print('pre : ' + str(pre))
    print('jsc : ' + str(jsc))
    print('mmc : ' + str(mmc))

print('ok')
