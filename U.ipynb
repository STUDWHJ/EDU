# %%
# coding: utf-8
import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
from skimage import exposure
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split, KFold
# Out:
# 2022-09-10 17:28:27.427044: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
img_files = next(os.walk(r"/home/weiweili/notebook/WHJ/images2/image"))[2]
msk_files = next(os.walk(r"/home/weiweili/notebook/WHJ/images2/lable"))[2]

img_files.sort()
msk_files.sort()
print(len(img_files))
print(len(msk_files))
# Out:
# 88
# 88

# %%
X = []
Y = []

for img_fl in tqdm(img_files):    
    if(img_fl.split('.')[-1]=='png'):
        img = cv2.imread('/home/weiweili/notebook/WHJ/images2/image/{}'.format(img_fl))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        resized_img = cv2.resize(img,(256, 192), interpolation = cv2.INTER_CUBIC)
        X.append(resized_img)
        
        msk = cv2.imread('/home/weiweili/notebook/WHJ/images2/lable/{}'.format(img_fl.split('.')[0]+'.png'),cv2.IMREAD_GRAYSCALE)
        resized_msk = cv2.resize(msk,(256, 192), interpolation = cv2.INTER_CUBIC)
        Y.append(resized_msk)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [00:00<00:00, 291.48it/s]

# %%
plt.figure(figsize=(10,5))
plt.imshow(resized_img)

# %%
plt.figure(figsize=(10,5))
plt.imshow(resized_msk)

# %%
print(len(X))
print(len(Y))
# Out:
# 88
# 88

# %%
X = np.array(X)

# %%
X
# Out:
# array([[[[ 5,  3,  4],
#          [ 0,  1,  0],
#          [ 3, 12,  1],
#          ...,
#          [ 4,  7,  0],
#          [ 0,  1,  0],
#          [ 0,  3,  0]],
#
#         [[ 8,  0,  0],
#          [ 5,  5,  0],
#          [12, 16,  9],
#          ...,
#          [ 5, 11,  0],
#          [ 0,  3,  0],
#          [ 1,  5,  0]],
#
#         [[ 6,  1,  0],
#          [ 4,  2,  1],
#          [ 9, 10,  8],
#          ...,
#          [ 2,  8,  0],
#          [ 1,  4,  0],
#          [ 9,  8,  3]],
#
#         ...,
#
#         [[ 7, 10,  0],
#          [ 0,  5,  0],
#          [ 5, 11,  0],
#          ...,
#          [ 7, 15,  0],
#          [ 3,  5,  0],
#          [ 6,  6,  0]],
#
#         [[ 0,  7,  0],
#          [ 0,  0,  0],
#          [ 4,  9,  0],
#          ...,
#          [ 6, 11,  0],
#          [ 0,  0,  0],
#          [ 2,  1,  0]],
#
#         [[ 4,  7,  0],
#          [ 0,  5,  0],
#          [ 5, 10,  0],
#          ...,
#          [ 5,  6,  0],
#          [ 0,  0,  0],
#          [ 1,  0,  0]]],
#
#
#        [[[ 4,  4,  5],
#          [ 0,  2,  0],
#          [ 3, 12,  2],
#          ...,
#          [ 4,  7,  0],
#          [ 0,  1,  0],
#          [ 0,  3,  0]],
#
#         [[ 8,  0,  0],
#          [ 5,  6,  0],
#          [12, 16,  8],
#          ...,
#          [ 5, 11,  0],
#          [ 0,  3,  0],
#          [ 1,  5,  0]],
#
#         [[ 7,  1,  0],
#          [ 4,  2,  1],
#          [ 9, 10,  7],
#          ...,
#          [ 2,  8,  0],
#          [ 1,  4,  0],
#          [ 8,  8,  3]],
#
#         ...,
#
#         [[ 4, 10,  0],
#          [ 0,  4,  0],
#          [ 2, 11,  0],
#          ...,
#          [ 7, 15,  0],
#          [ 2,  4,  0],
#          [ 6,  6,  0]],
#
#         [[ 0,  8,  0],
#          [ 0,  1,  0],
#          [ 3, 10,  0],
#          ...,
#          [ 6, 11,  0],
#          [ 0,  0,  0],
#          [ 3,  1,  0]],
#
#         [[ 4,  6,  0],
#          [ 0,  6,  0],
#          [ 5, 11,  0],
#          ...,
#          [ 4,  6,  0],
#          [ 0,  0,  0],
#          [ 3,  0,  0]]],
#
#
#        [[[ 0,  0,  0],
#          [ 3,  0,  1],
#          [ 0,  0,  2],
#          ...,
#          [17, 14,  9],
#          [ 3,  0,  0],
#          [ 0,  0,  6]],
#
#         [[ 0,  0,  7],
#          [ 0,  1,  8],
#          [ 0,  7,  7],
#          ...,
#          [ 0,  6,  9],
#          [ 0,  2,  3],
#          [ 1,  2,  5]],
#
#         [[ 0,  0,  5],
#          [ 0,  4,  7],
#          [ 0,  2,  8],
#          ...,
#          [ 0,  2, 14],
#          [ 0, 13, 11],
#          [ 3,  9, 14]],
#
#         ...,
#
#         [[ 9,  3, 10],
#          [ 0,  6,  4],
#          [ 0,  0,  7],
#          ...,
#          [ 0,  0,  3],
#          [ 0,  0, 10],
#          [ 4,  2,  6]],
#
#         [[ 1,  0,  2],
#          [ 0,  1,  2],
#          [ 0,  0, 12],
#          ...,
#          [ 0,  2,  4],
#          [ 0,  0,  5],
#          [ 1,  0,  5]],
#
#         [[ 3,  0,  0],
#          [ 0,  0,  0],
#          [ 0,  0,  9],
#          ...,
#          [ 0,  3,  3],
#          [ 0,  0,  0],
#          [ 0,  0,  2]]],
#
#
#        ...,
#
#
#        [[[ 0,  0,  0],
#          [ 3,  0,  1],
#          [ 0,  0,  3],
#          ...,
#          [17, 14,  9],
#          [ 3,  0,  0],
#          [ 0,  0,  6]],
#
#         [[ 0,  0,  7],
#          [ 0,  1,  8],
#          [ 0,  6,  7],
#          ...,
#          [ 0,  6,  9],
#          [ 0,  2,  3],
#          [ 1,  2,  5]],
#
#         [[ 0,  0,  6],
#          [ 0,  4,  7],
#          [ 0,  2,  9],
#          ...,
#          [ 0,  1, 13],
#          [ 0, 13, 11],
#          [ 4, 10, 15]],
#
#         ...,
#
#         [[ 8,  2,  9],
#          [ 0,  6,  4],
#          [ 0,  0,  7],
#          ...,
#          [ 0,  0,  3],
#          [ 0,  0, 10],
#          [ 4,  3,  6]],
#
#         [[ 1,  0,  1],
#          [ 0,  1,  2],
#          [ 0,  0, 12],
#          ...,
#          [ 0,  2,  4],
#          [ 0,  0,  5],
#          [ 1,  0,  5]],
#
#         [[ 4,  0,  0],
#          [ 0,  0,  0],
#          [ 0,  0,  9],
#          ...,
#          [ 0,  3,  4],
#          [ 0,  0,  0],
#          [ 0,  0,  2]]],
#
#
#        [[[ 0,  1,  0],
#          [ 8,  0,  2],
#          [ 0,  0,  3],
#          ...,
#          [17, 14,  9],
#          [ 2,  0,  0],
#          [ 0,  0,  6]],
#
#         [[ 0,  0,  7],
#          [ 0,  1,  9],
#          [ 0,  7, 10],
#          ...,
#          [ 0,  6,  9],
#          [ 0,  2,  2],
#          [ 1,  2,  5]],
#
#         [[ 0,  0,  5],
#          [ 0,  5,  7],
#          [ 0,  3, 10],
#          ...,
#          [ 0,  3, 14],
#          [ 0, 13, 11],
#          [ 3,  8, 14]],
#
#         ...,
#
#         [[ 8,  2, 10],
#          [ 0,  6,  4],
#          [ 0,  0,  6],
#          ...,
#          [ 0,  0,  3],
#          [ 0,  0, 10],
#          [ 4,  3,  6]],
#
#         [[ 1,  0,  2],
#          [ 0,  1,  2],
#          [ 0,  0, 13],
#          ...,
#          [ 0,  2,  4],
#          [ 0,  0,  5],
#          [ 1,  0,  5]],
#
#         [[ 3,  0,  0],
#          [ 0,  0,  0],
#          [ 0,  0, 10],
#          ...,
#          [ 0,  3,  3],
#          [ 0,  0,  0],
#          [ 0,  0,  2]]],
#
#
#        [[[ 0,  0,  0],
#          [ 4,  0,  2],
#          [ 0,  0,  3],
#          ...,
#          [17, 14,  9],
#          [ 2,  0,  0],
#          [ 0,  0,  6]],
#
#         [[ 0,  0,  7],
#          [ 0,  1,  8],
#          [ 0,  7,  8],
#          ...,
#          [ 0,  6,  9],
#          [ 0,  2,  3],
#          [ 1,  2,  5]],
#
#         [[ 0,  0,  6],
#          [ 0,  4,  7],
#          [ 0,  2,  9],
#          ...,
#          [ 0,  3, 14],
#          [ 0, 13, 11],
#          [ 3,  8, 15]],
#
#         ...,
#
#         [[ 8,  3,  9],
#          [ 0,  6,  5],
#          [ 0,  0,  7],
#          ...,
#          [ 0,  0,  3],
#          [ 0,  0, 10],
#          [ 4,  2,  6]],
#
#         [[ 1,  0,  1],
#          [ 0,  1,  3],
#          [ 0,  0, 12],
#          ...,
#          [ 0,  1,  4],
#          [ 0,  0,  5],
#          [ 1,  0,  5]],
#
#         [[ 3,  0,  0],
#          [ 0,  0,  0],
#          [ 0,  0, 10],
#          ...,
#          [ 0,  3,  3],
#          [ 0,  0,  0],
#          [ 0,  0,  3]]]], dtype=uint8)

# %%
Y = np.array(Y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

Y_train = Y_train.reshape((Y_train.shape[0],Y_train.shape[1],Y_train.shape[2],1))
Y_test = Y_test.reshape((Y_test.shape[0],Y_test.shape[1],Y_test.shape[2],1))

X_train = X_train / 255
X_test = X_test / 255
Y_train = Y_train / 255
Y_test = Y_test / 255

Y_train = np.round(Y_train,0)	
Y_test = np.round(Y_test,0)	

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (70, 192, 256, 3)
# (70, 192, 256, 1)
# (18, 192, 256, 3)
# (18, 192, 256, 1)

# %%
X_test1 = exposure.adjust_gamma(X_test, 2)

# %%
X_train1 = exposure.adjust_gamma(X_train, 2)

# %%
plt.imshow(X_train[0])

# %%
plt.imshow(Y_train[0])

# %%
Y_test[0].shape
# Out:
# (192, 256, 1)

# %%
plt.imshow(X_test[0])

# %%
plt.imshow(Y_test[0])

# %%
#MDE
def get_kernel():


    k1 = np.array([[1, -3, 1],
                   [-3,  8, -3],
                   [1, -3, 1]])
    
    # Sharpening Spatial Kernel, used in paper
    k2 = np.array([[-1, 0, 1],
                   [-1, 0, 1],
                   [-1, 0, 1]])
    
    k3 = np.array([[-1, -1, -1],
                   [0, 0, 0],
                   [1, 1, 1]])
    
    return k1, k2, k3


def build_MDE_blocks(layer):

    # Get number of channels in the feature
    in_channels = layer.shape[-1]
    # Get kernel
    _, w, _ = get_kernel()    
    # Change dimension
    w = np.expand_dims(w, axis=-1)
    # Repeat filter by in_channels times to get (H, W, in_channels)
    w = np.repeat(w, in_channels, axis=-1)
    # Expand dimension
    w = np.expand_dims(w, axis=-1)
    return w

# %%
def Net(img_size, num_classes):

    kernel_size = 3

    inputs = Input(img_size)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)
    

    
    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)
    
    
   
    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

   
    
    
    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)
    
    
    

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    # for multi-class segmentation, use the 'softmax' activation
    conv10 = Conv2D(num_classes, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])    
    
    return model

# %%
#custom metrics
smooth = 1

def jacard(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum ( y_true_f * y_pred_f)
    union = K.sum ( y_true_f + y_pred_f - y_true_f * y_pred_f)
    return intersection/union


def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
#modole callback
checkpointer = ModelCheckpoint("model.h5", verbose=0, monitor='val_loss', mode='min', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=1, min_lr=1e-8, mode='min')

# %%
# Build model
model = None
model = Net((192,256,3), 1)
model.summary()

# Compile model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy',
              metrics = [jacard, dice_coef])

# Train
epochs = 150
his = model.fit(X_train, Y_train,
                batch_size=2,
                epochs=epochs,
                validation_data=(X_test, Y_test),
                callbacks=[reduce_lr, checkpointer],
                shuffle=True)
# Out:
# 2022-09-10 17:28:30.022570: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-09-10 17:28:30.036620: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:d9:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-09-10 17:28:30.036659: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-10 17:28:30.038188: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-09-10 17:28:30.040048: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-09-10 17:28:30.040316: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-09-10 17:28:30.041925: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-09-10 17:28:30.042580: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-09-10 17:28:30.045985: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-09-10 17:28:30.048541: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-09-10 17:28:30.048957: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-10 17:28:30.057656: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 3400000000 Hz
# 2022-09-10 17:28:30.060065: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x563fd501fb80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-09-10 17:28:30.060081: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-09-10 17:28:30.191266: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x563fd5673830 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-09-10 17:28:30.191305: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-PCIE-32GB, Compute Capability 7.0
# 2022-09-10 17:28:30.192881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:d9:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-09-10 17:28:30.192937: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-10 17:28:30.192968: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-09-10 17:28:30.192980: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-09-10 17:28:30.192993: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-09-10 17:28:30.193004: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-09-10 17:28:30.193016: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-09-10 17:28:30.193028: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-09-10 17:28:30.195671: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-09-10 17:28:30.195712: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-10 17:28:30.641227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-09-10 17:28:30.641264: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2022-09-10 17:28:30.641270: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2022-09-10 17:28:30.643942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30132 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:d9:00.0, compute capability: 7.0)
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 192, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 192, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 192, 256, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 96, 128, 32)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 128, 64)  18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 128, 64)  36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 48, 64, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 64, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 64, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 24, 32, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 24, 32, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 24, 32, 256)  590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 16, 256)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 12, 16, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 12, 16, 512)  2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 24, 32, 256)  524544      conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 24, 32, 512)  0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 24, 32, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 24, 32, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 48, 64, 128)  131200      conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 48, 64, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 48, 64, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 48, 64, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 96, 128, 64)  32832       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 96, 128, 128) 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 96, 128, 64)  73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 96, 128, 64)  36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 192, 256, 32) 8224        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 192, 256, 64) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 192, 256, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 192, 256, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 192, 256, 1)  33          conv2d_17[0][0]
# ==================================================================================================
# Total params: 7,760,097
# Trainable params: 7,760,097
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/150
# 2022-09-10 17:28:32.323591: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-09-10 17:28:33.650542: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 35/35 [==============================] - 1s 28ms/step - loss: 0.5555 - jacard: 0.1139 - dice_coef: 0.2019 - val_loss: 0.4914 - val_jacard: 0.1623 - val_dice_coef: 0.2775
# Epoch 2/150
# 35/35 [==============================] - 0s 14ms/step - loss: 0.4438 - jacard: 0.1640 - dice_coef: 0.2795 - val_loss: 0.5095 - val_jacard: 0.1306 - val_dice_coef: 0.2302
# Epoch 3/150
# 35/35 [==============================] - 1s 19ms/step - loss: 0
- val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 127/150
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0458 - jacard: 0.8275 - dice_coef: 0.8983 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 128/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8328 - dice_coef: 0.9005 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 129/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8452 - dice_coef: 0.9126 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 130/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8326 - dice_coef: 0.9012 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 131/150
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0463 - jacard: 0.8307 - dice_coef: 0.9031
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 1e-08.
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0458 - jacard: 0.8361 - dice_coef: 0.9064 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 132/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8331 - dice_coef: 0.9039 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 133/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8381 - dice_coef: 0.9065 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 134/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8382 - dice_coef: 0.9068 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 135/150
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0458 - jacard: 0.8425 - dice_coef: 0.9101 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 136/150
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0458 - jacard: 0.8310 - dice_coef: 0.8985 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 137/150
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0458 - jacard: 0.8426 - dice_coef: 0.9091 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 138/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8328 - dice_coef: 0.9022 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 139/150
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0458 - jacard: 0.8302 - dice_coef: 0.8996 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 140/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8298 - dice_coef: 0.9000 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 141/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8427 - dice_coef: 0.9118 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 142/150
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0458 - jacard: 0.8418 - dice_coef: 0.9095 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 143/150
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0458 - jacard: 0.8265 - dice_coef: 0.8970 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 144/150
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0458 - jacard: 0.8458 - dice_coef: 0.9106 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 145/150
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0458 - jacard: 0.8359 - dice_coef: 0.9051 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 146/150
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0458 - jacard: 0.8349 - dice_coef: 0.9057 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 147/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8267 - dice_coef: 0.8932 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 148/150
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0458 - jacard: 0.8285 - dice_coef: 0.8968 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 149/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8350 - dice_coef: 0.9048 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009
# Epoch 150/150
# 35/35 [==============================] - 1s 14ms/step - loss: 0.0458 - jacard: 0.8329 - dice_coef: 0.9033 - val_loss: 0.0988 - val_jacard: 0.8225 - val_dice_coef: 0.9009

# %%
history = his.history
loss = history['loss']
jacard = history['jacard']
dice_coef = history['dice_coef']
val_loss = history['val_loss']
val_jacard = history['val_jacard']
val_dice_coef = history['val_dice_coef']

# %%
df = pd.DataFrame(history)
df.to_csv('/home/weiweili/notebook/WHJ/params2/unet_histtory.csv')

# %%
# Evaluatete
# Evaluate trained model using Jaccard and Dice metric
yp = model.predict(x=X_test, batch_size=2, verbose=0)
# Round off boolean masks
yp = np.round(yp, 0)

# %%
jacard = 0
dice = 0
sen = 0
pre = 0
jsc = 0
mmc = 0

for i in range(len(Y_test)):
    yp_2 = yp[i].ravel()
    y2 = Y_test[i].ravel()
    intersection = yp_2 * y2
    union = yp_2 + y2 - intersection
    jacard += (np.sum(intersection) / np.sum(union))
    dice += (2. * np.sum(intersection)) / (np.sum(yp_2) + np.sum(y2))
    TP = np.sum(yp_2 * y2)
    TN = np.sum((1-yp_2) * (1-y2))
    FP = np.sum(yp_2 * (1-y2))
    FN = np.sum(y2 * (1-yp_2))
    sen += TP/(TP+FN)
    pre += TP/(TP+FP)
    jsc += TP/(TP+FN+FP)
    mmc += (TP*TN-FP*FN)/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))

# %%
jacard /= len(Y_test)
dice /= len(Y_test)
sen /= len(Y_test)
pre /= len(Y_test)
jsc /= len(Y_test)
mmc /= len(Y_test)

print('Jacard Index : ' + str(jacard))
print('Dice Coefficient : ' + str(dice))
print('sen : ' + str(sen))
print('pre : ' + str(pre))
print('jsc : ' + str(jsc))
print('mmc : ' + str(mmc))
# Out:
# Jacard Index : 0.839518788900917
# Dice Coefficient : 0.9005725087232249
# sen : 0.9256946261161002
# pre : 0.8859843290348546
# jsc : 0.839518788900917
# mmc : 0.8816701600711428

# %%
os.makedirs('unet_res', exist_ok=True)
for i in range(20):
    plt.figure(figsize=(20, 5))
    plt.subplot(1, 3, 1)
    if len(X_test[i].shape) >= 2:
        plt.grid(False)
        plt.imshow(X_test[i].squeeze(), cmap='gray')  # 1-channel image
    else:
        plt.grid(False)
        plt.imshow(X_test[i])  # 3-channel

    plt.title('Input')
    plt.subplot(1, 3, 2)
    plt.grid(False)
    plt.imshow(Y_test[i].reshape(Y_test[i].shape[0], Y_test[i].shape[1]), cmap='magma')  # cmap='magma'
    plt.title('Ground Truth')
    plt.subplot(1, 3, 3)
    plt.grid(False)
    plt.imshow(yp[i].reshape(yp[i].shape[0], yp[i].shape[1]), cmap='magma')
    plt.title('Prediction')

    # Calc jaccard index of predictions
    intersection = yp[i].ravel() * Y_test[i].ravel()
    union = yp[i].ravel() + Y_test[i].ravel() - intersection
    jacard = (np.sum(intersection) / np.sum(union))

    plt.suptitle('Jacard Index: ' + str(np.sum(intersection)) + '/' + str(np.sum(union)) + ' = ' + str(jacard))
    plt.savefig(r"/home/weiweili/notebook/WHJ/params2/unet_res/test_%d.tif"%(i))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_208096/3019439590.py in <module>
#       3     plt.figure(figsize=(20, 5))
#       4     plt.subplot(1, 3, 1)
# ----> 5     if len(X_test[i].shape) >= 2:
#       6         plt.grid(False)
#       7         plt.imshow(X_test[i].squeeze(), cmap='gray')  # 1-channel image
#
# IndexError: index 18 is out of bounds for axis 0 with size 18

# %%
X = np.array(X)
Y = np.array(Y)
Y = Y.reshape((Y.shape[0], Y.shape[1], Y.shape[2], 1))
X = X / 255
Y = Y / 255
Y = np.round(Y, 0)
X = exposure.adjust_gamma(X, 1.5)

# %%
kf = KFold(n_splits=5)
k=0

# %%
for train_index, test_index in kf.split(X):
    k+=1
    X_train = X[train_index]
    Y_train = Y[train_index]
    X_test = X[test_index]
    Y_test = Y[test_index]

    def jacard(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        union = K.sum(y_true_f + y_pred_f - y_true_f * y_pred_f)
        return intersection / union

    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    model = SharpUNet((192, 256, 3), 1)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[jacard, dice_coef])
    
    epochs = 500
    his = model.fit(X_train, Y_train,
          batch_size=2,
          epochs=epochs,
          validation_data=(X_test, Y_test),
          callbacks=[reduce_lr],
          shuffle=True)
    history = his.history
    df = pd.DataFrame(history)
    df.to_csv('/home/weiweili/notebook/WHJ/params2/_unet-histtory_%d.csv'% (k))
    yp = model.predict(x=X_test, batch_size=2, verbose=0)
    yp = np.round(yp, 0)
    jacard = 0
    dice = 0
    sen = 0
    pre = 0
    jsc = 0
    mmc = 0

    for i in range(len(Y_test)):
        yp_2 = yp[i].ravel()
        y2 = Y_test[i].ravel()
        intersection = yp_2 * y2
        union = yp_2 + y2 - intersection
        jacard += (np.sum(intersection) / np.sum(union))
        dice += (2. * np.sum(intersection)) / (np.sum(yp_2) + np.sum(y2))
        TP = np.sum(yp_2 * y2)
        TN = np.sum((1 - yp_2) * (1 - y2))
        FP = np.sum(yp_2 * (1 - y2))
        FN = np.sum(y2 * (1 - yp_2))
        sen += TP / (TP + FN)
        pre += TP / (TP + FP)
        jsc += TP / (TP + FN + FP)
        mmc += (TP * TN - FP * FN) / np.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))

    jacard /= len(Y_test)
    dice /= len(Y_test)
    sen /= len(Y_test)
    pre /= len(Y_test)
    jsc /= len(Y_test)
    mmc /= len(Y_test)

    print("%d-th fold verification:" % (k))
    print('Jacard Index : ' + str(jacard))
    print('Dice Coefficient : ' + str(dice))
    print('sen : ' + str(sen))
    print('pre : ' + str(pre))
    print('jsc : ' + str(jsc))
    print('mmc : ' + str(mmc))

print('ok')
