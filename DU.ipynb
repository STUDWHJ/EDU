# %%
# coding: utf-8
import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
from skimage import exposure
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K, regularizers 
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split, KFold
# Out:
# 2022-09-10 16:45:57.152561: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
img_files = next(os.walk(r"/home/weiweili/notebook/WHJ/images2/image"))[2]
msk_files = next(os.walk(r"/home/weiweili/notebook/WHJ/images2/lable"))[2]
img_files.sort()
msk_files.sort()
print(len(img_files))
print(len(msk_files))
X = []
Y = []
for img_fl in tqdm(img_files):
    if (img_fl.split('.')[-1] == 'png'):
        img = cv2.imread('/home/weiweili/notebook/WHJ/images2/image/{}'.format(img_fl))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        resized_img = cv2.resize(img, (256, 192), interpolation=cv2.INTER_CUBIC)
        X.append(resized_img)

        msk = cv2.imread('/home/weiweili/notebook/WHJ/images2/lable/{}'.format(img_fl.split('.')[0] + '.png'), cv2.IMREAD_GRAYSCALE)
        resized_msk = cv2.resize(msk, (256, 192), interpolation=cv2.INTER_CUBIC)
        Y.append(resized_msk)
print(len(X))
print(len(Y))
# Out:
#  40%|████████████████████████████████████████████▉                                                                    | 35/88 [00:00<00:00, 347.57it/s]
# 88
# 88
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 88/88 [00:00<00:00, 329.49it/s]
# 88
# 88

# %%
plt.figure(figsize=(10, 5))
plt.imshow(resized_img)
plt.figure(figsize=(10, 5))
plt.imshow(resized_msk)

# %%
X = np.array(X)
Y = np.array(Y)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
Y_train = Y_train.reshape((Y_train.shape[0], Y_train.shape[1], Y_train.shape[2], 1))
Y_test = Y_test.reshape((Y_test.shape[0], Y_test.shape[1], Y_test.shape[2], 1))
X_train = X_train / 255
X_test = X_test / 255
Y_train = Y_train / 255
Y_test = Y_test / 255
Y_train = np.round(Y_train, 0)
Y_test = np.round(Y_test, 0)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (70, 192, 256, 3)
# (70, 192, 256, 1)
# (18, 192, 256, 3)
# (18, 192, 256, 1)

# %%
X_test1 = exposure.adjust_gamma(X_test, 1.5)
X_train1 = exposure.adjust_gamma(X_train, 1.5)

# %%
plt.imshow(np.array(X_train[0] * 255, np.uint8))
plt.imshow(np.array(Y_train[0][:, :, 0] * 255, np.uint8))
plt.imshow(np.array(X_test[0] * 255, np.uint8))
plt.imshow(np.array(Y_test[0][:, :, 0] * 255, np.uint8))

# %%
#MDE
def get_kernel():


    k1 = np.array([[1,-3, 1],
                   [-3,  8, -3],
                   [1, -3, 1]])
    
    # Sharpening Spatial Kernel, used in paper
    k2 = np.array([[-1, 0, 1],
                   [-1, 0, 1],
                   [-1, 0, 1]])
    
    k3 = np.array([[-1, -1, -1],
                   [0, 0, 0],
                   [1, 1, 1]])
    
    return k1, k2, k3

# %%
def build_MDE_blocks(layer):

    # Get number of channels in the feature
    in_channels = layer.shape[-1]
    # Get kernel
    _, w, _ = get_kernel()
    # Change dimension
    w = np.expand_dims(w, axis=-1)
    # Repeat filter by in_channels times to get (H, W, in_channels)
    w = np.repeat(w, in_channels, axis=-1)
    # Expand dimension
    w = np.expand_dims(w, axis=-1)
    return w

# %%
def DenseBlock(channels,inputs):

    conv1_1 = Conv2D(channels, (1, 1),activation=None, padding='same')(inputs)
    conv1_1=BatchActivate(conv1_1)
    conv1_2 = Conv2D(channels//4, (3, 3), activation=None, padding='same')(conv1_1)
    conv1_2 = BatchActivate(conv1_2)

    conv2=concatenate([inputs,conv1_2])
    conv2_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv2)
    conv2_1 = BatchActivate(conv2_1)
    conv2_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv2_1)
    conv2_2 = BatchActivate(conv2_2)

    conv3 = concatenate([inputs, conv1_2,conv2_2])
    conv3_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv3)
    conv3_1 = BatchActivate(conv3_1)
    conv3_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv3_1)
    conv3_2 = BatchActivate(conv3_2)

    conv4 = concatenate([inputs, conv1_2, conv2_2,conv3_2])
    conv4_1 = Conv2D(channels, (1, 1), activation=None, padding='same')(conv4)
    conv4_1 = BatchActivate(conv4_1)
    conv4_2 = Conv2D(channels // 4, (3, 3), activation=None, padding='same')(conv4_1)
    conv4_2 = BatchActivate(conv4_2)
    result=concatenate([inputs,conv1_2, conv2_2,conv3_2,conv4_2])
    return result

def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def Net(img_size, num_classes):

    # Kernel size for MDE blocks
    kernel_size = 3
    inputs = Input(img_size)

    # conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    # conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    # pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    #
    # conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    # conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    # pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    #
    # conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    # conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    # pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    #
    # conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    # conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    # pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    #
    # conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    # conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    start_neurons = 32

    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(inputs)
    conv1 = BatchActivate(conv1)
    pool0 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = DenseBlock(start_neurons * 1, pool0)

    pool1 = MaxPooling2D((2, 2))(conv2)
    conv3 = DenseBlock(start_neurons * 2, pool1)

    pool2 = MaxPooling2D((2, 2))(conv3)
    conv4 = DenseBlock(start_neurons * 4, pool2)

    pool3 = MaxPooling2D((2, 2))(conv4)
    conv5 = DenseBlock(start_neurons * 8, pool3)

    

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

   

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)


    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

   

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    # for multi-class segmentation, use the 'softmax' activation
    conv10 = Conv2D(num_classes, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])

    return model

# %%
# custom metrics
smooth = 1


def jacard(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f + y_pred_f - y_true_f * y_pred_f)
    return intersection / union


def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
# modole callback
checkpointer = ModelCheckpoint("densenet_unet_model.h5", verbose=0, monitor='val_loss', mode='min', save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=1, min_lr=1e-8, mode='min')

# %%
# Build model
model = Net((192, 256, 3), 1)
model.summary()
# Out:
# 2022-09-10 16:45:59.621097: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-09-10 16:45:59.632367: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:d9:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-09-10 16:45:59.632398: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-10 16:45:59.633878: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-09-10 16:45:59.635777: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-09-10 16:45:59.636026: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-09-10 16:45:59.637655: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-09-10 16:45:59.638286: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-09-10 16:45:59.641540: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-09-10 16:45:59.644056: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-09-10 16:45:59.644424: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-10 16:45:59.654146: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 3400000000 Hz
# 2022-09-10 16:45:59.657306: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ba331b35b0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-09-10 16:45:59.657326: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-09-10 16:45:59.774342: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ba335ff360 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-09-10 16:45:59.774400: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-PCIE-32GB, Compute Capability 7.0
# 2022-09-10 16:45:59.778546: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:d9:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2022-09-10 16:45:59.778630: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-10 16:45:59.778676: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-09-10 16:45:59.778707: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-09-10 16:45:59.778736: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-09-10 16:45:59.778764: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-09-10 16:45:59.778793: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-09-10 16:45:59.778822: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-09-10 16:45:59.784441: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2022-09-10 16:45:59.784488: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-10 16:46:00.207482: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-09-10 16:46:00.207520: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2022-09-10 16:46:00.207526: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2022-09-10 16:46:00.210182: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30132 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:d9:00.0, compute capability: 7.0)
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 192, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 192, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 192, 256, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 192, 256, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 96, 128, 32)  0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 96, 128, 32)  1056        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 96, 128, 32)  128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 96, 128, 32)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 128, 8)   2312        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 96, 128, 8)   32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 96, 128, 8)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 96, 128, 40)  0           max_pooling2d[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 128, 32)  1312        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 96, 128, 32)  128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 96, 128, 32)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 96, 128, 8)   2312        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 96, 128, 8)   32          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 96, 128, 8)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 96, 128, 48)  0           max_pooling2d[0][0]
#                                                                  activation_2[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 96, 128, 32)  1568        concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 96, 128, 32)  128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 96, 128, 32)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 96, 128, 8)   2312        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 96, 128, 8)   32          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 96, 128, 8)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 96, 128, 56)  0           max_pooling2d[0][0]
#                                                                  activation_2[0][0]
#                                                                  activation_4[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 96, 128, 32)  1824        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 96, 128, 32)  128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 96,
100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0714 - jacard: 0.7795 - dice_coef: 0.8732 - val_loss: 0.1971 - val_jacard: 0.6951 - val_dice_coef: 0.8131
# Epoch 26/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0657 - jacard: 0.7857 - dice_coef: 0.8773 - val_loss: 0.1999 - val_jacard: 0.6994 - val_dice_coef: 0.8180
# Epoch 27/100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0646 - jacard: 0.7886 - dice_coef: 0.8788 - val_loss: 0.1507 - val_jacard: 0.7181 - val_dice_coef: 0.8300
# Epoch 28/100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0606 - jacard: 0.8145 - dice_coef: 0.8960 - val_loss: 0.1671 - val_jacard: 0.7133 - val_dice_coef: 0.8261
# Epoch 29/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0612 - jacard: 0.8117 - dice_coef: 0.8943 - val_loss: 0.1750 - val_jacard: 0.7062 - val_dice_coef: 0.8207
# Epoch 30/100
# 35/35 [==============================] - 1s 35ms/step - loss: 0.0562 - jacard: 0.8131 - dice_coef: 0.8947 - val_loss: 0.1105 - val_jacard: 0.7509 - val_dice_coef: 0.8523
# Epoch 31/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0521 - jacard: 0.8327 - dice_coef: 0.9075 - val_loss: 0.1143 - val_jacard: 0.7563 - val_dice_coef: 0.8583
# Epoch 32/100
# 35/35 [==============================] - 1s 35ms/step - loss: 0.0468 - jacard: 0.8502 - dice_coef: 0.9181 - val_loss: 0.1082 - val_jacard: 0.7783 - val_dice_coef: 0.8729
# Epoch 33/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0467 - jacard: 0.8481 - dice_coef: 0.9163 - val_loss: 0.1241 - val_jacard: 0.7650 - val_dice_coef: 0.8635
# Epoch 34/100
# 35/35 [==============================] - 1s 35ms/step - loss: 0.0444 - jacard: 0.8613 - dice_coef: 0.9248 - val_loss: 0.0954 - val_jacard: 0.7716 - val_dice_coef: 0.8671
# Epoch 35/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0449 - jacard: 0.8611 - dice_coef: 0.9248 - val_loss: 0.1178 - val_jacard: 0.7727 - val_dice_coef: 0.8667
# Epoch 36/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0414 - jacard: 0.8670 - dice_coef: 0.9279 - val_loss: 0.1240 - val_jacard: 0.7726 - val_dice_coef: 0.8691
# Epoch 37/100
# 35/35 [==============================] - 1s 35ms/step - loss: 0.0425 - jacard: 0.8643 - dice_coef: 0.9266 - val_loss: 0.0757 - val_jacard: 0.8211 - val_dice_coef: 0.9001
# Epoch 38/100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0375 - jacard: 0.8777 - dice_coef: 0.9341 - val_loss: 0.1236 - val_jacard: 0.7755 - val_dice_coef: 0.8682
# Epoch 39/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0360 - jacard: 0.8792 - dice_coef: 0.9350 - val_loss: 0.0817 - val_jacard: 0.8117 - val_dice_coef: 0.8939
# Epoch 40/100
# 35/35 [==============================] - 1s 35ms/step - loss: 0.0353 - jacard: 0.8873 - dice_coef: 0.9398 - val_loss: 0.0668 - val_jacard: 0.8355 - val_dice_coef: 0.9080
# Epoch 41/100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0381 - jacard: 0.8706 - dice_coef: 0.9299 - val_loss: 0.1042 - val_jacard: 0.7933 - val_dice_coef: 0.8804
# Epoch 42/100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0341 - jacard: 0.8845 - dice_coef: 0.9379 - val_loss: 0.0874 - val_jacard: 0.8102 - val_dice_coef: 0.8918
# Epoch 43/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0334 - jacard: 0.8955 - dice_coef: 0.9446 - val_loss: 0.0886 - val_jacard: 0.8191 - val_dice_coef: 0.8966
# Epoch 44/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0400 - jacard: 0.8735 - dice_coef: 0.9316 - val_loss: 0.1120 - val_jacard: 0.7807 - val_dice_coef: 0.8704
# Epoch 45/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.
100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0174 - jacard: 0.9377 - dice_coef: 0.9677 - val_loss: 0.0646 - val_jacard: 0.8780 - val_dice_coef: 0.9338
# Epoch 86/100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0179 - jacard: 0.9385 - dice_coef: 0.9681 - val_loss: 0.0605 - val_jacard: 0.8822 - val_dice_coef: 0.9364
# Epoch 87/100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0176 - jacard: 0.9390 - dice_coef: 0.9685 - val_loss: 0.0606 - val_jacard: 0.8819 - val_dice_coef: 0.9362
# Epoch 88/100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0178 - jacard: 0.9389 - dice_coef: 0.9684 - val_loss: 0.0595 - val_jacard: 0.8836 - val_dice_coef: 0.9372
# Epoch 89/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0177 - jacard: 0.9399 - dice_coef: 0.9689 - val_loss: 0.0578 - val_jacard: 0.8853 - val_dice_coef: 0.9382
# Epoch 90/100
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0171 - jacard: 0.9400 - dice_coef: 0.9690 - val_loss: 0.0588 - val_jacard: 0.8841 - val_dice_coef: 0.9375
# Epoch 91/100
# 34/35 [============================>.] - ETA: 0s - loss: 0.0179 - jacard: 0.9383 - dice_coef: 0.9680
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0178 - jacard: 0.9386 - dice_coef: 0.9682 - val_loss: 0.0584 - val_jacard: 0.8843 - val_dice_coef: 0.9375
# Epoch 92/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0174 - jacard: 0.9395 - dice_coef: 0.9687 - val_loss: 0.0594 - val_jacard: 0.8832 - val_dice_coef: 0.9369
# Epoch 93/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0176 - jacard: 0.9367 - dice_coef: 0.9671 - val_loss: 0.0625 - val_jacard: 0.8802 - val_dice_coef: 0.9351
# Epoch 94/100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0175 - jacard: 0.9389 - dice_coef: 0.9684 - val_loss: 0.0638 - val_jacard: 0.8787 - val_dice_coef: 0.9342
# Epoch 95/100
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0171 - jacard: 0.9383 - dice_coef: 0.9680 - val_loss: 0.0647 - val_jacard: 0.8775 - val_dice_coef: 0.9334
# Epoch 96/100
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0177 - jacard: 0.9397 - dice_coef: 0.9688 - val_loss: 0.0658 - val_jacard: 0.8766 - val_dice_coef: 0.9329
# Epoch 97/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0177 - jacard: 0.9379 - dice_coef: 0.9678 - val_loss: 0.0631 - val_jacard: 0.8792 - val_dice_coef: 0.9345
# Epoch 98/100
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0182 - jacard: 0.9394 - dice_coef: 0.9686 - val_loss: 0.0637 - val_jacard: 0.8788 - val_dice_coef: 0.9343
# Epoch 99/100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0177 - jacard: 0.9367 - dice_coef: 0.9672 - val_loss: 0.0630 - val_jacard: 0.8799 - val_dice_coef: 0.9350
# Epoch 100/100
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0173 - jacard: 0.9400 - dice_coef: 0.9690 - val_loss: 0.0606 - val_jacard: 0.8823 - val_dice_coef: 0.9365

# %%
history = his.history
loss = history['loss']
jacard = history['jacard']
dice_coef = history['dice_coef']
val_loss = history['val_loss']
val_jacard = history['val_jacard']
val_dice_coef = history['val_dice_coef']

# %%
df = pd.DataFrame(history)
df.to_csv('/home/weiweili/notebook/WHJ/params2/densenet_unet_histtory.csv')

# %%
# Evaluatete
# Evaluate trained model using Jaccard and Dice metric
yp = model.predict(x=X_test, batch_size=2, verbose=0)
# Round off boolean masks
yp = np.round(yp, 0)

# %%
jacard = 0
dice = 0
sen = 0
pre = 0
jsc = 0
mmc = 0

for i in range(len(Y_test)):
    yp_2 = yp[i].ravel()
    y2 = Y_test[i].ravel()
    intersection = yp_2 * y2
    union = yp_2 + y2 - intersection
    jacard += (np.sum(intersection) / np.sum(union))
    dice += (2. * np.sum(intersection)) / (np.sum(yp_2) + np.sum(y2))
    TP = np.sum(yp_2 * y2)
    TN = np.sum((1-yp_2) * (1-y2))
    FP = np.sum(yp_2 * (1-y2))
    FN = np.sum(y2 * (1-yp_2))
    sen += TP/(TP+FN)
    pre += TP/(TP+FP)
    jsc += TP/(TP+FN+FP)
    mmc += (TP*TN-FP*FN)/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))

# %%
jacard /= len(Y_test)
dice /= len(Y_test)
sen /= len(Y_test)
pre /= len(Y_test)
jsc /= len(Y_test)
mmc /= len(Y_test)

print('Jacard Index : ' + str(jacard))
print('Dice Coefficient : ' + str(dice))
print('sen : ' + str(sen))
print('pre : ' + str(pre))
print('jsc : ' + str(jsc))
print('mmc : ' + str(mmc))
# Out:
# Jacard Index : 0.9016417058105183
# Dice Coefficient : 0.9472643425599594
# sen : 0.9751857466069244
# pre : 0.9239926562973692
# jsc : 0.9016417058105183
# mmc : 0.9335692992081834

# %%
os.makedirs('densenet_unet_res', exist_ok=True)
for i in range(6):
    plt.figure(figsize=(20, 5))
    plt.subplot(1, 3, 1)
    if len(X_test[i].shape) >= 2:
        plt.grid(False)
        plt.imshow(X_test[i].squeeze(), cmap='gray')  # 1-channel image
    else:
        plt.grid(False)
        plt.imshow(X_test[i])  # 3-channel

    plt.title('Input')
    plt.subplot(1, 3, 2)
    plt.grid(False)
    plt.imshow(Y_test[i].reshape(Y_test[i].shape[0], Y_test[i].shape[1]), cmap='magma')  # cmap='magma'
    plt.title('Ground Truth')
    plt.subplot(1, 3, 3)
    plt.grid(False)
    plt.imshow(yp[i].reshape(yp[i].shape[0], yp[i].shape[1]), cmap='magma')
    plt.title('Prediction')

    # Calc jaccard index of predictions
    intersection = yp[i].ravel() * Y_test[i].ravel()
    union = yp[i].ravel() + Y_test[i].ravel() - intersection
    jacard = (np.sum(intersection) / np.sum(union))

    plt.suptitle('Jacard Index: ' + str(np.sum(intersection)) + '/' + str(np.sum(union)) + ' = ' + str(jacard))
    plt.savefig(r"/home/weiweili/notebook/WHJ/params2/densenet_unet_res/test_%d.tif"%(i))
    plt.show()

# %%
X = np.array(X)
Y = np.array(Y)
Y = Y.reshape((Y.shape[0], Y.shape[1], Y.shape[2], 1))
X = X / 255
Y = Y / 255
Y = np.round(Y, 0)
X = exposure.adjust_gamma(X, 1.5)

# %%
kf = KFold(n_splits=5)
k=0

# %%
for train_index, test_index in kf.split(X):
    k+=1
    X_train = X[train_index]
    Y_train = Y[train_index]
    X_test = X[test_index]
    Y_test = Y[test_index]

    def jacard(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        union = K.sum(y_true_f + y_pred_f - y_true_f * y_pred_f)
        return intersection / union

    def dice_coef(y_true, y_pred):
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    model = SharpUNet((192, 256, 3), 1)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[jacard, dice_coef])
    
    epochs = 500
    his = model.fit(X_train, Y_train,
          batch_size=2,
          epochs=epochs,
          validation_data=(X_test, Y_test),
          callbacks=[reduce_lr],
          shuffle=True)
    history = his.history
    df = pd.DataFrame(history)
    df.to_csv('/home/weiweili/notebook/WHJ/params2/1densenet_unet-histtory_%d.csv'% (k))
    yp = model.predict(x=X_test, batch_size=2, verbose=0)
    yp = np.round(yp, 0)
    jacard = 0
    dice = 0
    sen = 0
    pre = 0
    jsc = 0
    mmc = 0

    for i in range(len(Y_test)):
        yp_2 = yp[i].ravel()
        y2 = Y_test[i].ravel()
        intersection = yp_2 * y2
        union = yp_2 + y2 - intersection
        jacard += (np.sum(intersection) / np.sum(union))
        dice += (2. * np.sum(intersection)) / (np.sum(yp_2) + np.sum(y2))
        TP = np.sum(yp_2 * y2)
        TN = np.sum((1 - yp_2) * (1 - y2))
        FP = np.sum(yp_2 * (1 - y2))
        FN = np.sum(y2 * (1 - yp_2))
        sen += TP / (TP + FN)
        pre += TP / (TP + FP)
        jsc += TP / (TP + FN + FP)
        mmc += (TP * TN - FP * FN) / np.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))

    jacard /= len(Y_test)
    dice /= len(Y_test)
    sen /= len(Y_test)
    pre /= len(Y_test)
    jsc /= len(Y_test)
    mmc /= len(Y_test)

    print("%d-th fold verification:" % (k))
    print('Jacard Index : ' + str(jacard))
    print('Dice Coefficient : ' + str(dice))
    print('sen : ' + str(sen))
    print('pre : ' + str(pre))
    print('jsc : ' + str(jsc))
    print('mmc : ' + str(mmc))

print('ok')
# Out:
# Epoch 1/500
# 35/35 [==============================] - 1s 40ms/step - loss: 0.4437 - jacard: 0.1568 - dice_coef: 0.2667 - val_loss: 0.6115 - val_jacard: 0.1727 - val_dice_coef: 0.2943
# Epoch 2/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.3528 - jacard: 0.2178 - dice_coef: 0.3543 - val_loss: 0.9928 - val_jacard: 0.0416 - val_dice_coef: 0.0793
# Epoch 3/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.3242 - jacard: 0.2721 - dice_coef: 0.4185 - val_loss: 0.5971 - val_jacard: 0.1421 - val_dice_coef: 0.2486
# Epoch 4/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.2977 - jacard: 0.3079 - dice_coef: 0.4625 - val_loss: 0.6929 - val_jacard: 0.1048 - val_dice_coef: 0.1890
# Epoch 5/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.2795 - jacard: 0.3466 - dice_coef: 0.5022 - val_loss: 0.7112 - val_jacard: 0.0906 - val_dice_coef: 0.1659
# Epoch 6/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.2252 - jacard: 0.4448 - dice_coef: 0.6031 - val_loss: 0.7416 - val_jacard: 0.2132 - val_dice_coef: 0.3440
# Epoch 7/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.2015 - jacard: 0.4758 - dice_coef: 0.6342 - val_loss: 1.1143 - val_jacard: 0.0708 - val_dice_coef: 0.1294
# Epoch 8/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.2130 - jacard: 0.4582 - dice_coef: 0.6105 - val_loss: 2.4130 - val_jacard: 0.0082 - val_dice_coef: 0.0162
# Epoch 9/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.1991 - jacard: 0.4586 - dice_coef: 0.6118 - val_loss: 10.7173 - val_jacard: 0.0875 - val_dice_coef: 0.1441
# Epoch 10/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.2644 - jacard: 0.4438 - dice_coef: 0.5965 - val_loss: 1.2880 - val_jacard: 0.1213 - val_dice_coef: 0.2141
# Epoch 11/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.1662 - jacard: 0.5414 - dice_coef: 0.6888 - val_loss: 0.9724 - val_jacard: 0.1507 - val_dice_coef: 0.2524
# Epoch 12/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.1293 - jacard: 0.6363 - dice_coef: 0.7674 - val_loss: 1.5174 - val_jacard: 0.0410 - val_dice_coef: 0.0710
# Epoch 13/500
# 35/35 [==============================] - ETA: 0s - loss: 0.1319 - jacard: 0.6162 - dice_coef: 0.7518
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 35/35 [==============================] - 1s 26ms/step - loss: 0.1319 - jacard: 0.6162 - dice_coef: 0.7518 - val_loss: 1.1184 - val_jacard: 0.2510 - val_dice_coef: 0.3904
# Epoch 14/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.1125 - jacard: 0.6685 - dice_coef: 0.7953 - val_loss: 1.3160 - val_jacard: 0.0579 - val_dice_coef: 0.1011
# Epoch 15/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0805 - jacard: 0.7364 - dice_coef: 0.8442 - val_loss: 1.3610 - val_jacard: 0.0514 - val_dice_coef: 0.0917
# Epoch 16/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0767 - jacard: 0.7518 - dice_coef: 0.8541 - val_loss: 1.1977 - val_jacard: 0.1239 - val_dice_coef: 0.1920
# Epoch 17/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0678 - jacard: 0.7741 - dice_coef: 0.8698 - val_loss: 0.9070 - val_jacard: 0.3031 - val_dice_coef: 0.4014
# Epoch 18/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0656 - jacard: 0.7795 - dice_coef: 0.8724 - val_loss: 0.7468 - val_jacard: 0.4032 - val_dice_coef: 0.4970
# Epoch 19/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0633 - jacard: 0.7948 - dice_coef: 0.8831 - val_loss: 0.7956 - val_jacard: 0.3947 - val_dice_coef: 0.4924
# Epoch 20/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0613 - jacard: 0.7829 - dice_coef: 0.8719 - val_loss: 0.7275 - val_jacard: 0.4401 - val_dice_coef: 0.5445
# Epoch 21/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0589 - jacard: 0.8039 - dice_coef: 0.8889 - val_loss: 0.6360 - val_jacard: 0.5006 - val_dice_coef: 0.6213
# Epoch 22/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0547 - jacard: 0.8193 - dice_coef: 0.8984 - val_loss: 0.3874 - val_jacard: 0.5967 - val_dice_coef: 0.7262
# Epoch 23/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0573 - jacard: 0.8026 - dice_coef: 0.8868 - val_loss: 0.2102 - val_jacard: 0.7653 - val_dice_coef: 0.8657
# Epoch 24/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0536 - jacard: 0.8058 - dice_coef: 0.8892 - val_loss: 0.3509 - val_jacard: 0.7350 - val_dice_coef: 0.8433
# Epoch 25/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0511 - jacard: 0.8207 - dice_coef: 0.8990 - val_loss: 0.1853 - val_jacard: 0.7548 - val_dice_coef: 0.8586
# Epoch 26/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0490 - jacard: 0.8251 - dice_coef: 0.9009 - val_loss: 0.1762 - val_jacard: 0.7795 - val_dice_coef: 0.8750
# Epoch 27/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0479 - jacard: 0.8335 - dice_coef: 0.9065 - val_loss: 0.1549 - val_jacard: 0.7862 - val_dice_coef: 0.8791
# Epoch 28/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0460 - jacard: 0.8261 - dice_coef: 0.9016 - val_loss: 0.1757 - val_jacard: 0.7679 - val_dice_coef: 0.8665
# Epoch 29/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0406 - jacard: 0.8517 - dice_coef: 0.9185 - val_loss: 0.2236 - val_jacard: 0.7510 - val_dice_coef: 0.8542
# Epoch 30/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0407 - jacard: 0.8559 - dice_coef: 0.9210 - val_loss: 0.3121 - val_jacard: 0.7042 - val_dice_coef: 0.8172
# Epoch 31/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0405 - jacard: 0.8545 - dice_coef: 0.9200 - val_loss: 0.1482 - val_jacard: 0.8030 - val_dice_coef: 0.8897
# Epoch 32/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0441 - jacard: 0.8611 - dice_coef: 0.9244 - val_loss: 0.1809 - val_jacard: 0.7747 - val_dice_coef: 0.8714
# Epoch 33/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0362 - jacard: 0.8684 - dice_coef: 0.9283 - val_loss: 0.1672 - val_jacard: 0.7967 - val_dice_coef: 0.8855
# Epoch 34/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0352 - jacard: 0.8649 - dice_coef: 0.9263 - val_loss: 0.2483 - val_jacard: 0.7527 - val_dice_coef: 0.8539
# Epoch 35/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0357 - jacard: 0.8786 - dice_coef: 0.9346 - val_loss: 0.1799 - val_jacard: 0.7993 - val_dice_coef: 0.8873
# Epoch 36/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0337 - jacard: 0.8785 - dice_coef: 0.9345 - val_loss: 0.2674 - val_jacard: 0.7459 - val_dice_coef: 0.8481
# Epoch 37/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0348 - jacard: 0.8766 - dice_coef: 0.9334 - val_loss: 0.2142 - val_jacard: 0.7806 - val_dice_coef: 0.8757
# Epoch 38/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0331 - jacard: 0.8758 - dice_coef: 0.9327 - val_loss: 0.1781 - val_jacard: 0.7850 - val_dice_coef: 0.8772
# Epoch 39/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0299 - jacard: 0.8913 - dice_coef: 0.9419 - val_loss: 0.2447 - val_jacard: 0.7556 - val_dice_coef: 0.8555
# Epoch 40/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0323 - jacard: 0.8862 - dice_coef: 0.9385 - val_loss: 0.1385 - val_jacard: 0.8227 - val_dice_coef: 0.9016
# Epoch 41/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0315 - jacard: 0.8783 - dice_coef: 0.9339 - val_loss: 0.1601 - val_jacard: 0.8095 - val_dice_coef: 0.8932
# Epoch 42/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0300 - jacard: 0.8914 - dice_coef: 0.9419 - val_loss: 0.2322 - val_jacard: 0.7616 - val_dice_coef: 0.8603
# Epoch 43/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0309 - jacard: 0.8889 - dice_coef: 0.9400 - val_loss: 0.1875 - val_jacard: 0.8179 - val_dice_coef: 0.8987
# Epoch 44/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0273 - jacard: 0.9008 - dice_coef: 0.9473 - val_loss: 0.1879 - val_jacard: 0.7883 - val_dice_coef: 0.8786
# Epoch 45/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0279 - jacard: 0.8939 - dice_coef: 0.9433 - val_loss: 0.2150 - val_jacard: 0.7796 - val_dice_coef: 0.8718
# Epoch 46/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0257 - jacard: 0.9026 - dice_coef: 0.9483 - val_loss: 0.1566 - val_jacard: 0.8200 - val_dice_coef: 0.8999
# Epoch 47/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0254 - jacard: 0.9057 - dice_coef: 0.9500 - val_loss: 0.1964 - val_jacard: 0.8206 - val_dice_coef: 0.9003
# Epoch 48/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0239 - jacard: 0.9138 - dice_coef: 0.9546 - val_loss: 0.1813 - val_jacard: 0.8182 - val_dice_coef: 0.8989
# Epoch 49/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0232 - jacard: 0.9107 - dice_coef: 0.9526 - val_loss: 0.2237 - val_jacard: 0.7831 - val_dice_coef: 0.8740
# Epoch 50/500
# 35/35 [==============================] - ETA: 0s - loss: 0.0214 - jacard: 0.9146 - dice_coef: 0.9550
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0214 - jacard: 0.9146 - dice_coef: 0.9550 - val_loss: 0.1927 - val_jacard: 0.8224 - val_dice_coef: 0.9012
# Epoch 51/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0215 - jacard: 0.9222 - dice_coef: 0.9592 - val_loss: 0.1893 - val_jacard: 0.8181 - val_dice_coef: 0.8986
# Epoch 52/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0229 - jacard: 0.9157 - dice_coef: 0.9557 - val_loss: 0.1872 - val_jacard: 0.8197 - val_dice_coef: 0.8996
# Epoch 53/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0215 - jacard: 0.9194 - dice_coef: 0.9577 - val_loss: 0.1853 - val_jacard: 0.8209 - val_dice_coef: 0.9004
# Epoch 54/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0216 - jacard: 0.9203 - dice_coef: 0.9582 - val_loss: 0.1894 - val_jacard: 0.8208 - val_dice_coef: 0.9003
# Epoch 55/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0203 - jacard: 0.9228 - dice_coef: 0.9595 - val_loss: 0.1912 - val_jacard: 0.8198 - val_dice_coef: 0.8997
# Epoch 56/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0202 - jacard: 0.9267 - dice_coef: 0.9617 - val_loss: 0.1895 - val_jacard: 0.8226 - val_dice_coef: 0.9014
# Epoch 57/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0200 - jacard: 0.9218 - dice_coef: 0.9590 - val_loss: 0.1852 - val_jacard: 0.8215 - val_dice_coef: 0.9007
# Epoch 58/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0209 - jacard: 0.9189 - dice_coef: 0.9574 - val_loss: 0.1865 - val_jacard: 0.8251 - val_dice_coef: 0.9030
# Epoch 59/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0208 - jacard: 0.9246 - dice_coef: 0.9606 - val_loss: 0.1812 - val_jacard: 0.8246 - val_dice_coef: 0.9027
# Epoch 60/500
# 34/35 [============================>.] - ETA: 0s - loss: 0.0208 - jacard: 0.9239 - dice_coef: 0.9602
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0205 - jacard: 0.9222 - dice_coef: 0.9592 - val_loss: 0.1878 - val_jacard: 0.8241 - val_dice_coef: 0.9023
# Epoch 61/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0202 - jacard: 0.9235 - dice_coef: 0.9599 - val_loss: 0.1899 - val_jacard: 0.8228 - val_dice_coef: 0.9016
# Epoch 62/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0206 - jacard: 0.9243 - dice_coef: 0.9605 - val_loss: 0.1902 - val_jacard: 0.8229 - val_dice_coef: 0.9016
# Epoch 63/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0202 - jacard: 0.9238 - dice_coef: 0.9601 - val_loss: 0.1966 - val_jacard: 0.8213 - val_dice_coef: 0.9006
# Epoch 64/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0210 - jacard: 0.9184 - dice_coef: 0.9567 - val_loss: 0.1900 - val_jacard: 0.8222 - val_dice_coef: 0.9012
# Epoch 65/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0204 - jacard: 0.9250 - dice_coef: 0.9607 - val_loss: 0.1890 - val_jacard: 0.8220 - val_dice_coef: 0.9010
# Epoch 66/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0200 - jacard: 0.9267 - dice_coef: 0.9618 - val_loss: 0.1875 - val_jacard: 0.8220 - val_dice_coef: 0.9010
# Epoch 67/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0201 - jacard: 0.9204 - dice_coef: 0.9582 - val_loss: 0.1911 - val_jacard: 0.8223 - val_dice_coef: 0.9013
# Epoch 68/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0197 - jacard: 0.9272 - dice_coef: 0.9620 - val_loss: 0.1886 - val_jacard: 0.8228 - val_dice_coef: 0.9016
# Epoch 69/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0220 - jacard: 0.9203 - dice_coef: 0.9582 - val_loss: 0.1888 - val_jacard: 0.8225 - val_dice_coef: 0.9013
# Epoch 70/500
# 34/35 [============================>.] - ETA: 0s - loss: 0.0196 - jacard: 0.9252 - dice_coef: 0.9609
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0197 - jacard: 0.9253 - dice_coef: 0.9610 - val_loss: 0.1895 - val_jacard: 0.8215 - val_dice_coef: 0.9008
# Epoch 71/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0209 - jacard: 0.9215 - dice_coef: 0.9589 - val_loss: 0.1940 - val_jacard: 0.8210 - val_dice_coef: 0.9005
# Epoch 72/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0202 - jacard: 0.9209 - dice_coef: 0.9584 - val_loss: 0.1933 - val_jacard: 0.8206 - val_dice_coef: 0.9002
# Epoch 73/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0216 - jacard: 0.9204 - dice_coef: 0.9581 - val_loss: 0.1944 - val_jacard: 0.8207 - val_dice_coef: 0.9002
# Epoch 74/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0198 - jacard: 0.9249 - dice_coef: 0.9607 - val_loss: 0.1931 - val_jacard: 0.8210 - val_dice_coef: 0.9005
# Epoch 75/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0220 - jacard: 0.9182 - dice_coef: 0.9569 - val_loss: 0.1928 - val_jacard: 0.8211 - val_dice_coef: 0.9005
# Epoch 76/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0204 - jacard: 0.9209 - dice_coef: 0.9584 - val_loss: 0.1939 - val_jacard: 0.8206 - val_dice_coef: 0.9002
# Epoch 77/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0203 - jacard: 0.9201 - dice_coef: 0.9580 - val_loss: 0.1966 - val_jacard: 0.8197 - val_dice_coef: 0.8997
# Epoch 78/500
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0208 - jacard: 0.9188 - dice_coef: 0.9572 - val_loss: 0.1975 - val_jacard: 0.8196 - val_dice_coef: 0.8995
# Epoch 79/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0196 - jacard: 0.9247 - dice_coef: 0.9606 - val_loss: 0.1930 - val_jacard: 0.8204 - val_dice_coef: 0.9001
# Epoch 80/500
# 34/35 [============================>.] - ETA: 0s - loss: 0.0200 - jacard: 0.9245 - dice_coef: 0.9605
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0199 - jacard: 0.9233 - dice_coef: 0.9598 - val_loss: 0.1918 - val_jacard: 0.8199 - val_dice_coef: 0.8998
# Epoch 81/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0206 - jacard: 0.9165 - dice_coef: 0.9559 - val_loss: 0.1955 - val_jacard: 0.8197 - val_dice_coef: 0.8996
# Epoch 82/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0200 - jacard: 0.9225 - dice_coef: 0.9594 - val_loss: 0.1940 - val_jacard: 0.8197 - val_dice_coef: 0.8996
# Epoch 83/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0219 - jacard: 0.9246 - dice_coef: 0.9606 - val_loss: 0.1920 - val_jacard: 0.8201 - val_dice_coef: 0.8999
# Epoch 84/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0205 - jacard: 0.9225 - dice_coef: 0.9594 - val_loss: 0.1930 - val_jacard: 0.8205 - val_dice_coef: 0.9002
# Epoch 85/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0214 - jacard: 0.9197 - dice_coef: 0.9578 - val_loss: 0.1924 - val_jacard: 0.8211 - val_dice_coef: 0.9005
# Epoch 86/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0212 - jacard: 0.9169 - dice_coef: 0.9562 - val_loss: 0.1928 - val_jacard: 0.8211 - val_dice_coef: 0.9005
# Epoch 87/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0200 - jacard: 0.9206 - dice_coef: 0.9583 - val_loss: 0.1950 - val_jacard: 0.8210 - val_dice_coef: 0.9004
# Epoch 88/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0203 - jacard: 0.9249 - dice_coef: 0.9607 - val_loss: 0.1924 - val_jacard: 0.8215 - val_dice_coef: 0.9007
# Epoch 89/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0200 - jacard: 0.9176 - dice_coef: 0.9566 - val_loss: 0.1954 - val_jacard: 0.8203 - val_dice_coef: 0.9000
# Epoch 90/500
# 34/35 [============================>.] - ETA: 0s - loss: 0.0209 - jacard: 0.9243 - dice_coef: 0.9604
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 1e-08.
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0213 - jacard: 0.9224 - dice_coef: 0.9594 - val_loss: 0.1919 - val_jacard: 0.8203 - val_dice_coef: 0.9000
# Epoch 91/500
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0224 - jacard: 0.9198 - dice_coef: 0.9578 - val_loss: 0.1932 - val_jacard: 0.8204 - val_dice_coef: 0.9001
# Epoch 92/500
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0206 - jacard: 0.9172 - dice_coef: 0.9562 - val_loss: 0.1917 - val_jacard: 0.8193 - val_dice_coef: 0.8994
# Epoch 93/500
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0198 - jacard: 0.9253 - dice_coef: 0.9609 - val_loss: 0.1898 - val_jacard: 0.8201 - val_dice_coef: 0.8999
# Epoch 94/500
# 27/35 [======================>.......] - ETA: 0s - loss: 0.0204 - jacard: 0.9151 - dice_coef: 0.9551
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_175657/1029055693.py in <module>
#      28           validation_data=(X_test, Y_test),
#      29           callbacks=[reduce_lr],
# ---> 30           shuffle=True)
#      31     history = his.history
#      32     df = pd.DataFrame(history)
#
# ~/anaconda3/envs/WHJ/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/WHJ/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/anaconda3/envs/WHJ/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/anaconda3/envs/WHJ/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/WHJ/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/anaconda3/envs/WHJ/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/WHJ/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/anaconda3/envs/WHJ/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/WHJ/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
